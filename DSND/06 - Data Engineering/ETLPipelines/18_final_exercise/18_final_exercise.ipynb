# %% [markdown]
# # Final Exercise - Putting it All Together
#
# In this last exercise, you'll write a full ETL pipeline for the GDP data. That means you'll extract the World Bank data, transform the data, and load the data all in one go. In other words, you'll want one Python script that can do the entire process.
#
# Why would you want to do this? Imagine working for a company that creates new data every day. As new data comes in, you'll want to write software that periodically and automatically extracts, transforms, and loads the data.
#
# To give you a sense for what this is like, you'll extract the GDP data one line at a time. You'll then transform that line of data and load the results into a SQLite database. The code in this exercise is somewhat tricky.
#
# Here is an explanation of how this Jupyter notebook is organized:
# 1. The first cell connects to a SQLite database called worldbank.db and creates a table to hold the gdp data. You do not need to do anything in this code cell other than executing the cell.
# 2. The second cell has a function called `extract_line()`. You don't need to do anything in this code cell either besides executing the cell. This function is a [Python generator](https://wiki.python.org/moin/Generators). You don't need to understand how this works in order to complete the exercise. Essentially, a generator is like a regular function except instead of a return statement, a generator has a yield statement. Generators allow you to use functions in a for loop. In essence, this function will allow you to read in a data file one line at a time, run a transformation on that row of data, and then move on to the next row in the file.
# 3. The third cell contains a function called `transform_indicator_data()`. This function receives a line from the csv file and transforms the data in preparation for a load step.
# 4. The fourth cell contains a function called `load_indicator_data()`, which loads the trasnformed data into the gdp table in the worldbank.db database.
# 5. The fifth cell runs the ETL pipeilne
# 6. The sixth cell runs a query against the database to make sure everything worked correctly.
#
# You'll need to modify the third and fourth cells.

# %%
# run this cell to create a database and a table, called gdp, to hold the gdp data
# You do not need to change anything in this code cell

import sqlite3

# connect to the database
# the database file will be worldbank.db
# note that sqlite3 will create this database file if it does not exist already
conn = sqlite3.connect('worldbank.db')

# get a cursor
cur = conn.cursor()

# drop the test table in case it already exists
cur.execute("DROP TABLE IF EXISTS gdp")

# create the test table including project_id as a primary key
cur.execute("CREATE TABLE gdp (countryname TEXT, countrycode TEXT, year INTEGER, gdp REAL, PRIMARY KEY (countrycode, year));")

conn.commit()
conn.close()

# %%
# Generator for reading in one line at a time
# generators are useful for data sets that are too large to fit in RAM
# You do not need to change anything in this code cell
def extract_lines(file):
    while True:
        line = file.readline()
        if not line:
            break
        yield line

# %%
# TODO: fill out the code wherever you find a TODO in this cell
# This function has two inputs:
#   data, which is a row of data from the gdp csv file
#   colnames, which is a list of column names from the csv file
# The output should be a list of [countryname, countrycode, year, gdp] values
# In other words, the output would look like:
# [[Aruba, ABW, 1994, 1.330168e+09], [Aruba, ABW, 1995, 1.320670e+09], ...]
#

import pandas as pd
import numpy as np
import sqlite3

# transform the indicator data
def transform_indicator_data(data, colnames):
    
    # get rid of quote marks
    for i, datum in enumerate(data):
        data[i] = datum.replace('"','')
    
    # TODO: the data variable contains a list of data in the form [countryname, countrycode, 1960, 1961, 1962,...]
    # since this is the format of the data in the csv file. Extract the countryname from the list 
    # and put the result in the country variable
    country = data[0]
    
    # these are "countryname" values that are not actually countries
    non_countries = ['World',
     'High income',
     'OECD members',
     'Post-demographic dividend',
     'IDA & IBRD total',
     'Low & middle income',
     'Middle income',
     'IBRD only',
     'East Asia & Pacific',
     'Europe & Central Asia',
     'North America',
     'Upper middle income',
     'Late-demographic dividend',
     'European Union',
     'East Asia & Pacific (excluding high income)',
     'East Asia & Pacific (IDA & IBRD countries)',
     'Euro area',
     'Early-demographic dividend',
     'Lower middle income',
     'Latin America & Caribbean',
     'Latin America & the Caribbean (IDA & IBRD countries)',
     'Latin America & Caribbean (excluding high income)',
     'Europe & Central Asia (IDA & IBRD countries)',
     'Middle East & North Africa',
     'Europe & Central Asia (excluding high income)',
     'South Asia (IDA & IBRD)',
     'South Asia',
     'Arab World',
     'IDA total',
     'Sub-Saharan Africa',
     'Sub-Saharan Africa (IDA & IBRD countries)',
     'Sub-Saharan Africa (excluding high income)',
     'Middle East & North Africa (excluding high income)',
     'Middle East & North Africa (IDA & IBRD countries)',
     'Central Europe and the Baltics',
     'Pre-demographic dividend',
     'IDA only',
     'Least developed countries: UN classification',
     'IDA blend',
     'Fragile and conflict affected situations',
     'Heavily indebted poor countries (HIPC)',
     'Low income',
     'Small states',
     'Other small states',
     'Not classified',
     'Caribbean small states',
     'Pacific island small states']
    
    # filter out country name values that are in the above list
    if country not in non_countries:
        
        # In this section, you'll convert the single row of data into a data frame
        # The advantage of converting a single row of data into a data frame is that you can
        # re-use code from earlier in the lesson to clean the data
        
        # TODO: convert the data variable into a numpy array
        # Use the ndmin=2 option
        data_array = np.array(data, ndmin=2)
        
        # TODO: reshape the data_array so that it is one row and 63 columns
        data_array.reshape(1, 63)
        
        # TODO: convert the data_array variable into a pandas dataframe
        # Note that you can specify the column names as well using the colnames variable
        # Also, replace all empty strings in the dataframe with nan (HINT: Use the replace module and np.nan)
        df = pd.DataFrame(data=data_array, columns=colnames).replace('', np.nan)
        
        # TODO: Drop the 'Indicator Name' and 'Indicator Code' columns
        df.drop(['\n', 'Indicator Name', 'Indicator Code'], inplace=True, axis=1)
        
        # TODO: Reshape the data sets so that they are in long format
        # The id_vars should be Country Name and Country Code
        # You can name the variable column year and the value column gdp
        # HINT: Use the pandas melt() method
        # HINT: This was already done in a previous exercise
        df_melt = df.melt(id_vars=['Country Name', 'Country Code'], var_name='year', value_name='gdp')
        
        # TODO: Iterate through the rows in df_melt
        # For each row, extract the country, countrycode, year, and gdp values into a list like this:
        #     [country, countrycode, year, gdp]
        # If the gdp value is not null, append the row (in the form of a list) to the results variable
        # Finally, return the results list after iterating through the df_melt data
        # HINT: the iterrows() method would be useful
        # HINT: to check if gdp is equal to nan, you might want to convert gdp to a string and compare to the
        #       string 'nan
        results = []
        for index, row in df_melt.iterrows():
            country, countrycode, year, gdp = row
            if str(gdp) != 'nan':
                results.append([country, countrycode, year, gdp])
        return results

# %%
# TODO: fill out the code wherever you find a TODO in this cell
# This function loads data into the gdp table of the worldbank.db database
# The input is a list of data outputted from the transformation step that looks like this:
# [[Aruba, ABW, 1994, 1.330168e+09], [Aruba, ABW, 1995, 1.320670e+09], ...]

# The function does not return anything. Instead, the function iterates through the input and inserts each
# value into the gdp data set.

def load_indicator_data(results):
    
    # TODO: connect to the worldbank.db database using the sqlite3 library
    conn = sqlite3.connect('worldbank.db')
    
    # TODO: create a cursor object
    cur = conn.cursor()
    
    if results:
        
        # iterate through the results variable and insert each result into the gdp table
        for result in results:
            
            # TODO: extract the countryname, countrycode, year, and gdp from each iteration
            countryname, countrycode, year, gdp = result

            # TODO: prepare a query to insert a countryname, countrycode, year, gdp value
            sql_string = 'INSERT INTO gdp (countryname, countrycode, year, gdp) VALUES ("{}", "{}", {}, {});'.format(countryname, countrycode, year, gdp)

            # connect to database and execute query
            try:
                cur.execute(sql_string)
            # print out any errors (like if the primary key constraint is violated)
            except Exception as e:
                print('error occurred:', e, result)
    
    # commit changes and close the connection
    conn.commit()
    conn.close()
    
    return None

# %%
# Execute this code cell to run the ETL pipeline
# You do not need to change anything in this cell

# open the data file
with open('../data/gdp_data.csv') as f:
    # execute the generator to read in the file line by line
    for line in extract_lines(f):
        # split the comma separated values
        data = line.split(',')
        # check the length of the line because the first four lines of the csv file are not data
        if len(data) == 63:
            # check if the line represents column names
            if data[0] == '"Country Name"':
                colnames = []
                # get rid of quote marks in the results to make the data easier to work with
                for i, datum in enumerate(data):
                    colnames.append(datum.replace('"',''))
            else:
                # transform and load the line of indicator data
                results = transform_indicator_data(data, colnames)
                load_indicator_data(results)
# Out:
# error occurred: database is locked ['Aruba', 'ABW', '1994', '1330167597.76536']
# error occurred: database is locked ['Aruba', 'ABW', '1995', '1320670391.06145']
# error occurred: database is locked ['Aruba', 'ABW', '1996', '1379888268.15642']
# error occurred: database is locked ['Aruba', 'ABW', '1997', '1531843575.41899']
# error occurred: database is locked ['Aruba', 'ABW', '1998', '1665363128.49162']
# error occurred: database is locked ['Aruba', 'ABW', '1999', '1722798882.68156']
# error occurred: database is locked ['Aruba', 'ABW', '2000', '1873452513.96648']
# error occurred: database is locked ['Aruba', 'ABW', '2001', '1920262569.8324']
# error occurred: database is locked ['Aruba', 'ABW', '2002', '1941094972.06704']
# error occurred: database is locked ['Aruba', 'ABW', '2003', '2021301675.97765']
# error occurred: database is locked ['Aruba', 'ABW', '2004', '2228279329.60894']
# error occurred: database is locked ['Aruba', 'ABW', '2005', '2331005586.59218']
# error occurred: database is locked ['Aruba', 'ABW', '2006', '2421474860.3352']
# error occurred: database is locked ['Aruba', 'ABW', '2007', '2623726256.98324']
# error occurred: database is locked ['Aruba', 'ABW', '2008', '2791960893.85475']
# error occurred: database is locked ['Aruba', 'ABW', '2009', '2498932960.89385']
# error occurred: database is locked ['Aruba', 'ABW', '2010', '2467703910.61453']
# error occurred: database is locked ['Aruba', 'ABW', '2011', '2584463687.15084']
# error occurred: database is locked ['Afghanistan', 'AFG', '1960', '537777811.111111']
# error occurred: database is locked ['Afghanistan', 'AFG', '1961', '548888895.555556']
# error occurred: database is locked ['Afghanistan', 'AFG', '1962', '546666677.777778']
# error occurred: database is locked ['Afghanistan', 'AFG', '1963', '751111191.111111']
# error occurred: database is locked ['Afghanistan', 'AFG', '1964', '800000044.444444']
# error occurred: database is locked ['Afghanistan', 'AFG', '1965', '1006666637.77778']
# error occurred: database is locked ['Afghanistan', 'AFG', '1966', '1399999966.66667']
# error occurred: database is locked ['Afghanistan', 'AFG', '1967', '1673333417.77778']
# error occurred: database is locked ['Afghanistan', 'AFG', '1968', '1373333366.66667']
# error occurred: database is locked ['Afghanistan', 'AFG', '1969', '1408888922.22222']
# error occurred: database is locked ['Afghanistan', 'AFG', '1970', '1748886595.55556']
# error occurred: database is locked ['Afghanistan', 'AFG', '1971', '1831108971.11111']
# error occurred: database is locked ['Afghanistan', 'AFG', '1972', '1595555475.55556']
# error occurred: database is locked ['Afghanistan', 'AFG', '1973', '1733333264.44444']
# error occurred: database is locked ['Afghanistan', 'AFG', '1974', '2155555497.77778']
# error occurred: database is locked ['Afghanistan', 'AFG', '1975', '2366666615.55556']
# error occurred: database is locked ['Afghanistan', 'AFG', '1976', '2555555566.66667']
# error occurred: database is locked ['Afghanistan', 'AFG', '1977', '2953333417.77778']
# error occurred: database is locked ['Afghanistan', 'AFG', '1978', '3300000108.88889']
# error occurred: database is locked ['Afghanistan', 'AFG', '1979', '3697940409.61098']
# error occurred: database is locked ['Afghanistan', 'AFG', '1980', '3641723321.99546']
# error occurred: database is locked ['Afghanistan', 'AFG', '1981', '3478787909.09091']
# error occurred: database is locked ['Afghanistan', 'AFG', '2001', '2461665937.89386']
# error occurred: database is locked ['Afghanistan', 'AFG', '2002', '4128820723.04713']
# error occurred: database is locked ['Afghanistan', 'AFG', '2003', '4583644246.48061']
# error occurred: database is locked ['Afghanistan', 'AFG', '2004', '5285465685.86423']
# error occurred: database is locked ['Afghanistan', 'AFG', '2005', '6275073571.54659']
# error occurred: database is locked ['Afghanistan', 'AFG', '2006', '7057598406.61553']
# error occurred: database is locked ['Afghanistan', 'AFG', '2007', '9843842455.48323']
# error occurred: database is locked ['Afghanistan', 'AFG', '2008', '10190529882.4878']
# error occurred: database is locked ['Afghanistan', 'AFG', '2009', '12486943505.7381']
# error occurred: database is locked ['Afghanistan', 'AFG', '2010', '15936800636.2487']
# error occurred: database is locked ['Afghanistan', 'AFG', '2011', '17930239399.8149']
# error occurred: database is locked ['Afghanistan', 'AFG', '2012', '20536542736.7297']
# error occurred: database is locked ['Afghanistan', 'AFG', '2013', '20264253973.7858']
# error occurred: database is locked ['Afghanistan', 'AFG', '2014', '20616104298.4975']
# error occurred: database is locked ['Afghanistan', 'AFG', '2015', '19215562179.0117']
# error occurred: database is locked ['Afghanistan', 'AFG', '2016', '19469022207.6852']
# error occurred: database is locked ['Afghanistan', 'AFG', '2017', '20815300220.0428']
# error occurred: database is locked ['Angola', 'AGO', '1980', '5934073603.54849']
# error occurred: database is locked ['Angola', 'AGO', '1981', '5553824463.82274']
# error occurred: database is locked ['Angola', 'AGO', '1982', '5553824463.82274']
# error occurred: database is locked ['Angola', 'AGO', '1983', '5787823808.69565']
# error occurred: database is locked ['Angola', 'AGO', '1984', '6135166254.2408']
# error occurred: database is locked ['Angola', 'AGO', '1985', '7558613007.90635']
# error occurred: database is locked ['Angola', 'AGO', '1986', '7076793822.60201']
# error occurred: database is locked ['Angola', 'AGO', '1987', '8089279284.72241']
# error occurred: database is locked ['Angola', 'AGO', '1988', '8775116269.16722']
# error occurred: database is locked ['Angola', 'AGO', '1989', '10207922517.1839']
# error occurred: database is locked ['Angola', 'AGO', '1990', '11236275842.7358']
# error occurred: database is locked ['Angola', 'AGO', '1994', '3390500000']
# error occurred: database is locked ['Angola', 'AGO', '1995', '5561222222.22222']
# error occurred: database is locked ['Angola', 'AGO', '1996', '6537503912.36307']
# error occurred: database is locked ['Angola', 'AGO', '1997', '7676533742.33129']
# error occurred: database is locked ['Angola', 'AGO', '1998', '6506619144.60285']
# error occurred: database is locked ['Angola', 'AGO', '1999', '6152936539.21955']
# error occurred: database is locked ['Angola', 'AGO', '2000', '9129634978.33773']
# error occurred: database is locked ['Angola', 'AGO', '2001', '8936063723.20121']
# error occurred: database is locked ['Angola', 'AGO', '2002', '12497347956.1316']
# error occurred: database is locked ['Angola', 'AGO', '2003', '14188949398.3752']
# error occurred: database is locked ['Angola', 'AGO', '2004', '19640853733.598']
# error occurred: database is locked ['Angola', 'AGO', '2005', '28233712737.97']
# error occurred: database is locked ['Angola', 'AGO', '2006', '41789479931.7142']
# error occurred: database is locked ['Angola', 'AGO', '2007', '60448924661.7935']
# error occurred: database is locked ['Angola', 'AGO', '2008', '84178035578.8223']
# error occurred: database is locked ['Angola', 'AGO', '2009', '75492385928.3332']
# error occurred: database is locked ['Angola', 'AGO', '2010', '82526143645.0623']
# error occurred: database is locked ['Angola', 'AGO', '2011', '104115807985.965']
# error occurred: database is locked ['Angola', 'AGO', '2012', '113923162050.111']
# error occurred: database is locked ['Angola', 'AGO', '2013', '124912503781.148']
# error occurred: database is locked ['Angola', 'AGO', '2014', '126730196125.425']
# error occurred: database is locked ['Angola', 'AGO', '2015', '102621215573.456']
# error occurred: database is locked ['Angola', 'AGO', '2016', '95337203468.1156']
# error occurred: database is locked ['Angola', 'AGO', '2017', '124209385825.22']
# error occurred: database is locked ['Albania', 'ALB', '1984', '1924242453.00929']
# error occurred: database is locked ['Albania', 'ALB', '1985', '1965384586.24229']
# error occurred: database is locked ['Albania', 'ALB', '1986', '2173750012.5']
# error occurred: database is locked ['Albania', 'ALB', '1987', '2156624900']
# error occurred: database is locked ['Albania', 'ALB', '1988', '2126000000']
# error occurred: database is locked ['Albania', 'ALB', '1989', '2335124987.5']
# error occurred: database is locked ['Albania', 'ALB', '1990', '2101624962.5']
# error occurred: database is locked ['Albania', 'ALB', '1991', '1139166645.83333']
# error occurred: database is locked ['Albania', 'ALB', '1992', '709452583.880319']
# error occurred: database is locked ['Albania', 'ALB', '1993', '1228071037.84446']
# error occurred: database is locked ['Albania', 'ALB', '1994', '1985673798.10258']
# error occurred: database is locked ['Albania', 'ALB', '1995', '2424499009.14264']
# error occurred: database is locked ['Albania', 'ALB', '1996', '3314898291.75235']
# error occurred: database is locked ['Albania', 'ALB', '1997', '2359903108.38446']
# error occurred: database is locked ['Albania', 'ALB', '1998', '2707123772.16195']
# error occurred: database is locked ['Albania', 'ALB', '1999', '3414760915.27878']
# error occurred: database is locked ['Albania', 'ALB', '2000', '3632043907.97733']
# error occurred: database is locked ['Albania', 'ALB', '2001', '4060758804.12084']
# error occurred: database is locked ['Albania', 'ALB', '2002', '4435078647.74817']
# error occurred: database is locked ['Albania', 'ALB', '2003', '5746945912.58082']
# error occurred: database is locked ['Albania', 'ALB', '2004', '7314865175.6199']
# error occurred: database is locked ['Albania', 'ALB', '2005', '8158548716.68554']
# error occurred: database is locked ['Albania', 'ALB', '2006', '8992642348.7871']
# error occurred: database is locked ['Albania', 'ALB', '2007', '10701011896.7708']
# error occurred: database is locked ['Albania', 'ALB', '2008', '12881352687.7773']
# error occurred: database is locked ['Albania', 'ALB', '2009', '12044212903.8168']
# error occurred: database is locked ['Albania', 'ALB', '2010', '11926953258.916']
# error occurred: database is locked ['Albania', 'ALB', '2011', '12890867538.5302']
# error occurred: database is locked ['Albania', 'ALB', '2012', '12319784787.2987']
# error occurred: database is locked ['Albania', 'ALB', '2013', '12776277515.48']
# error occurred: database is locked ['Albania', 'ALB', '2014', '13228244357.1813']
# error occurred: database is locked ['Albania', 'ALB', '2015', '11386931489.7968']
# error occurred: database is locked ['Albania', 'ALB', '2016', '11883682170.8236']
# error occurred: database is locked ['Albania', 'ALB', '2017', '13039352743.9616']
# error occurred: database is locked ['Andorra', 'AND', '1970', '78619206.0850963']
# error occurred: database is locked ['Andorra', 'AND', '1971', '89409820.3592814']
# error occurred: database is locked ['Andorra', 'AND', '1972', '113408231.944085']
# error occurred: database is locked ['Andorra', 'AND', '1973', '150820102.798401']
# error occurred: database is locked ['Andorra', 'AND', '1974', '186558696.279204']
# error occurred: database is locked ['Andorra', 'AND', '1975', '220127246.376812']
# error occurred: database is locked ['Andorra', 'AND', '1976', '227281024.620741']
# error occurred: database is locked ['Andorra', 'AND', '1977', '254020153.340635']
# error occurred: database is locked ['Andorra', 'AND', '1978', '308008897.569444']
# error occurred: database is locked ['Andorra', 'AND', '1979', '411578334.159643']
# error occurred: database is locked ['Andorra', 'AND', '1980', '446416105.825017']
# error occurred: database is locked ['Andorra', 'AND', '1981', '388958731.302938']
# error occurred: database is locked ['Andorra', 'AND', '1982', '375895956.383462']
# error occurred: database is locked ['Andorra', 'AND', '1983', '327861832.946636']
# error occurred: database is locked ['Andorra', 'AND', '1984', '330070689.298282']
# error occurred: database is locked ['Andorra', 'AND', '1985', '346737964.774951']
# error occurred: database is locked ['Andorra', 'AND', '1986', '482000594.03588']
# error occurred: database is locked ['Andorra', 'AND', '1987', '611316399.407088']
# error occurred: database is locked ['Andorra', 'AND', '1988', '721425939.15155']
# error occurred: database is locked ['Andorra', 'AND', '1989', '795449332.396346']
# error occurred: database is locked ['Andorra', 'AND', '1990', '1029048481.88051']
# error occurred: database is locked ['Andorra', 'AND', '1991', '1106928582.86629']
# error occurred: database is locked ['Andorra', 'AND', '1992', '1210013651.87713']
# error occurred: database is locked ['Andorra', 'AND', '1993', '1007025755.00065']
# error occurred: database is locked ['Andorra', 'AND', '1994', '1017549124.33238']
# error occurred: database is locked ['Andorra', 'AND', '1995', '1178738991.19295']
# error occurred: database is locked ['Andorra', 'AND', '1996', '1223945356.62682']
# error occurred: database is locked ['Andorra', 'AND', '1997', '1180597272.72727']
# error occurred: database is locked ['Andorra', 'AND', '1998', '1211932397.81713']
# error occurred: database is locked ['Andorra', 'AND', '1999', '1239876305.13531']
# error occurred: database is locked ['Andorra', 'AND', '2000', '1434429703.33518']
# error occurred: database is locked ['Andorra', 'AND', '2001', '1496912751.67785']
# error occurred: database is locked ['Andorra', 'AND', '2002', '1733116883.11688']
# error occurred: database is locked ['Andorra', 'AND', '2003', '2398645598.19413']
# error occurred: database is locked ['Andorra', 'AND', '2004', '2935659299.72684']
# error occurred: database is locked ['Andorra', 'AND', '2005', '3255789080.96008']
# error occurred: database is locked ['Andorra', 'AND', '2006', '3543256805.92147']
# error occurred: database is locked ['Andorra', 'AND', '2007', '4016972351.49192']
# error occurred: database is locked ['Andorra', 'AND', '2008', '4007353156.58415']
# error occurred: database is locked ['Andorra', 'AND', '2009', '3660530702.97305']
# error occurred: database is locked ['Andorra', 'AND', '2010', '3355695364.23841']
# error occurred: database is locked ['Andorra', 'AND', '2011', '3442062830.13622']
# error occurred: database is locked ['Andorra', 'AND', '2012', '3164615186.94591']
# error occurred: database is locked ['Andorra', 'AND', '2013', '3281585236.32501']
# error occurred: database is locked ['Andorra', 'AND', '2014', '3350736367.25488']
# error occurred: database is locked ['Andorra', 'AND', '2015', '2811489408.89431']
# error occurred: database is locked ['Andorra', 'AND', '2016', '2877311946.90265']
# error occurred: database is locked ['Andorra', 'AND', '2017', '3012914131.16971']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1975', '14720672506.5004']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1976', '19213022691.0526']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1977', '24871775164.6043']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1978', '23775831783.4263']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1979', '31225463217.7582']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1980', '43598748449.0479']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1981', '49333424135.1131']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1982', '46622718605.2847']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1983', '42803323345.1376']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1984', '41807954235.903']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1985', '40603650231.5445']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1986', '33943612094.7971']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1987', '36384908744.2114']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1988', '36275674203.2144']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1989', '41464995913.9199']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1990', '50701443748.2975']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1991', '51552165622.4462']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1992', '54239171887.769']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1993', '55625170253.337']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1994', '59305093979.842']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1995', '65743666575.8649']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1996', '73571233996.1863']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1997', '78839008444.5655']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1998', '75674336283.1858']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '1999', '84445473110.9598']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2000', '104337372362.151']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2001', '103311640571.818']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2002', '109816201497.617']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2003', '124346358066.712']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2004', '147824370319.946']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2005', '180617018379.85']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2006', '222116541865.214']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2007', '257916133424.098']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2008', '315474615738.598']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2009', '253547358747.447']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2010', '289787338325.391']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2011', '350666031313.819']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2012', '374590605854.323']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2013', '390107556160.654']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2014', '403137100068.073']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2015', '358135057862.492']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2016', '357045064669.843']
# error occurred: database is locked ['United Arab Emirates', 'ARE', '2017', '382575085091.899']
# error occurred: database is locked ['Argentina', 'ARG', '1971', '16646599770']
# error occurred: database is locked ['Argentina', 'ARG', '1972', '27786400318']
# error occurred: database is locked ['Argentina', 'ARG', '1973', '47289600372']
# error occurred: database is locked ['Argentina', 'ARG', '1974', '65193099976']
# error occurred: database is locked ['Argentina', 'ARG', '1975', '48505749702.5']
# error occurred: database is locked ['Argentina', 'ARG', '1976', '51169498443.6']
# error occurred: database is locked ['Argentina', 'ARG', '1977', '56780999755.86']
# error occurred: database is locked ['Argentina', 'ARG', '1978', '58082870733.541']
# error occurred: database is locked ['Argentina', 'ARG', '1979', '69252330274.1362']
# error occurred: database is locked ['Argentina', 'ARG', '1980', '76961921890.6573']
# error occurred: database is locked ['Argentina', 'ARG', '1981', '78676840049.3421']
# error occurred: database is locked ['Argentina', 'ARG', '1982', '84307484567.9012']
# error occurred: database is locked ['Argentina', 'ARG', '1983', '103979107312.441']
# error occurred: database is locked ['Argentina', 'ARG', '1984', '79092000000']
# error occurred: database is locked ['Argentina', 'ARG', '1985', '88416666666.6667']
# error occurred: database is locked ['Argentina', 'ARG', '1986', '110934444444.444']
# error occurred: database is locked ['Argentina', 'ARG', '1987', '111106190476.19']
# error occurred: database is locked ['Argentina', 'ARG', '1988', '126206818181.818']
# error occurred: database is locked ['Argentina', 'ARG', '1989', '76636898126.1883']
# error occurred: database is locked ['Argentina', 'ARG', '1990', '141352368724.031']
# error occurred: database is locked ['Argentina', 'ARG', '1991', '189719984268.485']
# error occurred: database is locked ['Argentina', 'ARG', '1992', '228788617201.696']
# error occurred: database is locked ['Argentina', 'ARG', '1993', '236741715015.015']
# error occurred: database is locked ['Argentina', 'ARG', '1994', '257440000000']
# error occurred: database is locked ['Argentina', 'ARG', '1995', '258031750000']
# error occurred: database is locked ['Argentina', 'ARG', '1996', '272149750000']
# error occurred: database is locked ['Argentina', 'ARG', '1997', '292859000000']
# error occurred: database is locked ['Argentina', 'ARG', '1998', '298948250000']
# error occurred: database is locked ['Argentina', 'ARG', '1999', '283523000000']
# error occurred: database is locked ['Argentina', 'ARG', '2000', '284203750000']
# error occurred: database is locked ['Argentina', 'ARG', '2001', '268696750000']
# error occurred: database is locked ['Argentina', 'ARG', '2002', '97724004251.8602']
# error occurred: database is locked ['Argentina', 'ARG', '2003', '127586973492.177']
# error occurred: database is locked ['Argentina', 'ARG', '2004', '164657930452.787']
# error occurred: database is locked ['Argentina', 'ARG', '2005', '198737095012.282']
# error occurred: database is locked ['Argentina', 'ARG', '2006', '232557260817.308']
# error occurred: database is locked ['Argentina', 'ARG', '2007', '287530508430.568']
# error occurred: database is locked ['Argentina', 'ARG', '2008', '361558037110.419']
# error occurred: database is locked ['Argentina', 'ARG', '2009', '332976484577.619']
# error occurred: database is locked ['Argentina', 'ARG', '2010', '423627422092.49']
# error occurred: database is locked ['Argentina', 'ARG', '2011', '530163281574.658']
# error occurred: database is locked ['Argentina', 'ARG', '2012', '545982375701.128']
# error occurred: database is locked ['Argentina', 'ARG', '2013', '552025140252.246']
# error occurred: database is locked ['Argentina', 'ARG', '2014', '526319673731.638']
# error occurred: database is locked ['Argentina', 'ARG', '2015', '594749285413.212']
# error occurred: database is locked ['Argentina', 'ARG', '2016', '554860945013.62']
# error occurred: database is locked ['Argentina', 'ARG', '2017', '637590419269.324']
# error occurred: database is locked ['Armenia', 'ARM', '1990', '2256838857.60997']
# error occurred: database is locked ['Armenia', 'ARM', '1991', '2069870129.87013']
# error occurred: database is locked ['Armenia', 'ARM', '1992', '1272835453.42634']
# error occurred: database is locked ['Armenia', 'ARM', '1993', '1201312829.27524']
# error occurred: database is locked ['Armenia', 'ARM', '1994', '1315158636.67553']
# error occurred: database is locked ['Armenia', 'ARM', '1995', '1468317435.20148']
# error occurred: database is locked ['Armenia', 'ARM', '1996', '1596968946.23708']
# error occurred: database is locked ['Armenia', 'ARM', '1997', '1639492444.76152']
# error occurred: database is locked ['Armenia', 'ARM', '1998', '1893726437.26462']
# error occurred: database is locked ['Armenia', 'ARM', '1999', '1845482173.02732']
# error occurred: database is locked ['Armenia', 'ARM', '2000', '1911563668.85006']
# error occurred: database is locked ['Armenia', 'ARM', '2001', '2118467913.37873']
# error occurred: database is locked ['Armenia', 'ARM', '2002', '2376335048.39976']
# error occurred: database is locked ['Armenia', 'ARM', '2003', '2807061008.69084']
# error occurred: database is locked ['Armenia', 'ARM', '2004', '3576615240.41616']
# error occurred: database is locked ['Armenia', 'ARM', '2005', '4900469950.09033']
# error occurred: database is locked ['Armenia', 'ARM', '2006', '6384451606.1421']
# error occurred: database is locked ['Armenia', 'ARM', '2007', '9206301700.39619']
# error occurred: database is locked ['Armenia', 'ARM', '2008', '11662040713.8753']
# error occurred: database is locked ['Armenia', 'ARM', '2009', '8647936747.98704']
# error occurred: database is locked ['Armenia', 'ARM', '2010', '9260284937.79782']
# error occurred: database is locked ['Armenia', 'ARM', '2011', '10142111334.4961']
# error occurred: database is locked ['Armenia', 'ARM', '2012', '10619320048.5857']
# error occurred: database is locked ['Armenia', 'ARM', '2013', '11121465767.4067']
# error occurred: database is locked ['Armenia', 'ARM', '2014', '11609512939.7543']
# error occurred: database is locked ['Armenia', 'ARM', '2015', '10553337672.9872']
# error occurred: database is locked ['Armenia', 'ARM', '2016', '10546135160.031']
# error occurred: database is locked ['Armenia', 'ARM', '2017', '11536590635.8268']
# error occurred: database is locked ['American Samoa', 'ASM', '2002', '514000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2003', '527000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2004', '512000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2005', '503000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2006', '496000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2007', '520000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2008', '563000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2009', '678000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2010', '576000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2011', '574000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2012', '644000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2013', '641000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2014', '643000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2015', '659000000']
# error occurred: database is locked ['American Samoa', 'ASM', '2016', '658000000']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1977', '77496740.7407407']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1978', '87879333.3333333']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1979', '109079962.962963']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1980', '131431037.037037']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1981', '147841740.740741']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1982', '164369296.296296']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1983', '182144111.111111']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1984', '208372851.851852']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1985', '240923925.925926']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1986', '290440148.148148']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1987', '337174851.851852']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1988', '398637740.740741']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1989', '438794777.777778']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1990', '459469074.074074']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1991', '481706333.333333']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1992', '499281148.148148']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1993', '535172777.777778']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1994', '589429592.592593']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1995', '577280740.740741']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1996', '633730629.62963']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1997', '680617111.111111']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1998', '727860592.592593']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '1999', '766198925.925926']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2000', '830158777.777778']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2001', '800740259.259259']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2002', '814615333.333333']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2003', '855643111.111111']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2004', '919577148.148148']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2005', '1022191296.2963']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2006', '1157005444.44444']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2007', '1311401333.33333']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2008', '1368431037.03704']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2009', '1224253000']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2010', '1152469074.07407']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2011', '1142042925.92593']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2012', '1211411703.7037']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2013', '1192925407.40741']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2014', '1280133333.33333']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2015', '1364863037.03704']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2016', '1460144703.7037']
# error occurred: database is locked ['Antigua and Barbuda', 'ATG', '2017', '1532397555.55556']
# error occurred: database is locked ['Australia', 'AUS', '1960', '18573188486.9526']
# error occurred: database is locked ['Australia', 'AUS', '1961', '19648336879.8298']
# error occurred: database is locked ['Australia', 'AUS', '1962', '19888005375.742']
# error occurred: database is locked ['Australia', 'AUS', '1963', '21501847911.3003']
# error occurred: database is locked ['Australia', 'AUS', '1964', '23758539590.0997']
# error occurred: database is locked ['Australia', 'AUS', '1965', '25931235300.7056']
# error occurred: database is locked ['Australia', 'AUS', '1966', '27261731436.891']
# error occurred: database is locked ['Australia', 'AUS', '1967', '30389741292.418']
# error occurred: database is locked ['Australia', 'AUS', '1968', '32657632433.6432']
# error occurred: database is locked ['Australia', 'AUS', '1969', '36620002239.8925']
# error occurred: database is locked ['Australia', 'AUS', '1970', '41261059469.1455']
# error occurred: database is locked ['Australia', 'AUS', '1971', '45138313360.9587']
# error occurred: database is locked ['Australia', 'AUS', '1972', '51954439252.3364']
# error occurred: database is locked ['Australia', 'AUS', '1973', '63721973094.1704']
# error occurred: database is locked ['Australia', 'AUS', '1974', '88809137803.9794']
# error occurred: database is locked ['Australia', 'AUS', '1975', '97147343984.7057']
# error occurred: database is locked ['Australia', 'AUS', '1976', '104894743476.617']
# error occurred: database is locked ['Australia', 'AUS', '1977', '110174351915.577']
# error occurred: database is locked ['Australia', 'AUS', '1978', '118309271373.787']
# error occurred: database is locked ['Australia', 'AUS', '1979', '134679086674.997']
# error occurred: database is locked ['Australia', 'AUS', '1980', '149738161559.889']
# error occurred: database is locked ['Australia', 'AUS', '1981', '176599326599.327']
# error occurred: database is locked ['Australia', 'AUS', '1982', '193721725697.893']
# error occurred: database is locked ['Australia', 'AUS', '1983', '176986429574.169']
# error occurred: database is locked ['Australia', 'AUS', '1984', '193194167723.239']
# error occurred: database is locked ['Australia', 'AUS', '1985', '180190994860.781']
# error occurred: database is locked ['Australia', 'AUS', '1986', '181977476217.124']
# error occurred: database is locked ['Australia', 'AUS', '1987', '189041159343.568']
# error occurred: database is locked ['Australia', 'AUS', '1988', '235699941792.782']
# error occurred: database is locked ['Australia', 'AUS', '1989', '299317645142.904']
# error occurred: database is locked ['Australia', 'AUS', '1990', '310838014621.008']
# error occurred: database is locked ['Australia', 'AUS', '1991', '325358292127.776']
# error occurred: database is locked ['Australia', 'AUS', '1992', '324878105052.68']
# error occurred: database is locked ['Australia', 'AUS', '1993', '311528948847.667']
# error occurred: database is locked ['Australia', 'AUS', '1994', '322201314424.075']
# error occurred: database is locked ['Australia', 'AUS', '1995', '367216364716.365']
# error occurred: database is locked ['Australia', 'AUS', '1996', '400302731411.229']
# error occurred: database is locked ['Australia', 'AUS', '1997', '434568007512.913']
# error occurred: database is locked ['Australia', 'AUS', '1998', '398899138574.239']
# error occurred: database is locked ['Australia', 'AUS', '1999', '388395162301.04']
# error occurred: database is locked ['Australia', 'AUS', '2000', '415034227218.489']
# error occurred: database is locked ['Australia', 'AUS', '2001', '378215090694.43']
# error occurred: database is locked ['Australia', 'AUS', '2002', '394486709920.469']
# error occurred: database is locked ['Australia', 'AUS', '2003', '466294700058.241']
# error occurred: database is locked ['Australia', 'AUS', '2004', '611904253805.662']
# error occurred: database is locked ['Australia', 'AUS', '2005', '692641708013.833']
# error occurred: database is locked ['Australia', 'AUS', '2006', '745521862833.184']
# error occurred: database is locked ['Australia', 'AUS', '2007', '851962785585.303']
# error occurred: database is locked ['Australia', 'AUS', '2008', '1052584601611.46']
# error occurred: database is locked ['Australia', 'AUS', '2009', '926448240318.068']
# error occurred: database is locked ['Australia', 'AUS', '2010', '1144260547872.81']
# error occurred: database is locked ['Australia', 'AUS', '2011', '1394280784777.68']
# error occurred: database is locked ['Australia', 'AUS', '2012', '1543411012579.91']
# error occurred: database is locked ['Australia', 'AUS', '2013', '1573696522006.77']
# error occurred: database is locked ['Australia', 'AUS', '2014', '1464955475993.76']
# error occurred: database is locked ['Australia', 'AUS', '2015', '1349034029453.37']
# error occurred: database is locked ['Australia', 'AUS', '2016', '1208039015868.39']
# error occurred: database is locked ['Australia', 'AUS', '2017', '1323421072479.07']
# error occurred: database is locked ['Austria', 'AUT', '1960', '6592693841.18495']
# error occurred: database is locked ['Austria', 'AUT', '1961', '7311749633.36229']
# error occurred: database is locked ['Austria', 'AUT', '1962', '7756110210.11966']
# error occurred: database is locked ['Austria', 'AUT', '1963', '8374175257.73075']
# error occurred: database is locked ['Austria', 'AUT', '1964', '9169983885.71185']
# error occurred: database is locked ['Austria', 'AUT', '1965', '9994070615.85997']
# error occurred: database is locked ['Austria', 'AUT', '1966', '10887682273.1014']
# error occurred: database is locked ['Austria', 'AUT', '1967', '11579431668.9165']
# error occurred: database is locked ['Austria', 'AUT', '1968', '12440625312.8685']
# error occurred: database is locked ['Austria', 'AUT', '1969', '13582798556.2404']
# error occurred: database is locked ['Austria', 'AUT', '1970', '15373005768.7219']
# error occurred: database is locked ['Austria', 'AUT', '1971', '17858485956.6031']
# error occurred: database is locked ['Austria', 'AUT', '1972', '22059612417.4058']
# error occurred: database is locked ['Austria', 'AUT', '1973', '29515467987.912']
# error occurred: database is locked ['Austria', 'AUT', '1974', '35189299985.2768']
# error occurred: database is locked ['Austria', 'AUT', '1975', '40059206763.056']
# error occurred: database is locked ['Austria', 'AUT', '1976', '42959976068.1138']
# error occurred: database is locked ['Austria', 'AUT', '1977', '51545759220.7143']
# error occurred: database is locked ['Austria', 'AUT', '1978', '62052258694.2102']
# error occurred: database is locked ['Austria', 'AUT', '1979', '73937296654.6577']
# error occurred: database is locked ['Austria', 'AUT', '1980', '82058912465.4329']
# error occurred: database is locked ['Austria', 'AUT', '1981', '71034228097.4598']
# error occurred: database is locked ['Austria', 'AUT', '1982', '71275287327.5793']
# error occurred: database is locked ['Austria', 'AUT', '1983', '72121016623.2572']
# error occurred: database is locked ['Austria', 'AUT', '1984', '67985345161.9558']
# error occurred: database is locked ['Austria', 'AUT', '1985', '69386774474.5943']
# error occurred: database is locked ['Austria', 'AUT', '1986', '99036165209.5539']
# error occurred: database is locked ['Austria', 'AUT', '1987', '124168442860.253']
# error occurred: database is locked ['Austria', 'AUT', '1988', '133339397080.129']
# error occurred: database is locked ['Austria', 'AUT', '1989', '133105805928.237']
# error occurred: database is locked ['Austria', 'AUT', '1990', '166463386663.439']
# error occurred: database is locked ['Austria', 'AUT', '1991', '173794177725.398']
# error occurred: database is locked ['Austria', 'AUT', '1992', '195078126346.106']
# error occurred: database is locked ['Austria', 'AUT', '1993', '190379720927.481']
# error occurred: database is locked ['Austria', 'AUT', '1994', '203535242741.838']
# error occurred: database is locked ['Austria', 'AUT', '1995', '241038283062.645']
# error occurred: database is locked ['Austria', 'AUT', '1996', '237250948791.266']
# error occurred: database is locked ['Austria', 'AUT', '1997', '212790348404.555']
# error occurred: database is locked ['Austria', 'AUT', '1998', '218259904401.956']
# error occurred: database is locked ['Austria', 'AUT', '1999', '217185787342.851']
# error occurred: database is locked ['Austria', 'AUT', '2000', '196799778883.361']
# error occurred: database is locked ['Austria', 'AUT', '2001', '197337879194.631']
# error occurred: database is locked ['Austria', 'AUT', '2002', '213377771503.858']
# error occurred: database is locked ['Austria', 'AUT', '2003', '261695778781.038']
# error occurred: database is locked ['Austria', 'AUT', '2004', '300904221504.842']
# error occurred: database is locked ['Austria', 'AUT', '2005', '315974418604.651']
# error occurred: database is locked ['Austria', 'AUT', '2006', '335998557270.104']
# error occurred: database is locked ['Austria', 'AUT', '2007', '388691445387.353']
# error occurred: database is locked ['Austria', 'AUT', '2008', '430294287388.311']
# error occurred: database is locked ['Austria', 'AUT', '2009', '400172297860.517']
# error occurred: database is locked ['Austria', 'AUT', '2010', '391892746544.69']
# error occurred: database is locked ['Austria', 'AUT', '2011', '431120310088.82']
# error occurred: database is locked ['Austria', 'AUT', '2012', '409425234155.263']
# error occurred: database is locked ['Austria', 'AUT', '2013', '430068712971.867']
# error occurred: database is locked ['Austria', 'AUT', '2014', '441885415805.825']
# error occurred: database is locked ['Austria', 'AUT', '2015', '382065930307.978']
# error occurred: database is locked ['Austria', 'AUT', '2016', '390799991147.468']
# error occurred: database is locked ['Austria', 'AUT', '2017', '416595666396.636']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1990', '8858006042.29607']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1991', '5344000000']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1992', '4820100000']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1993', '3976759493.67089']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1994', '3312797524.31477']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1995', '3052646638.05436']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1996', '3176749593.11788']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1997', '3962710163.11167']
# error occurred: database is locked ['Azerbaijan', 'AZE', '1998', '4446394417.16206']

# %%
# Execute this code cell to output the values in the gdp table
# You do not need to change anything in this cell

# connect to the database
# the database file will be worldbank.db
# note that sqlite3 will create this database file if it does not exist already
conn = sqlite3.connect('worldbank.db')

# get a cursor
cur = conn.cursor()

# create the test table including project_id as a primary key
df = pd.read_sql("SELECT * FROM gdp", con=conn)

conn.commit()
conn.close()

df

# %% [markdown]
# # Conclusion
#
# ETL Pipelines involve extracting data from one source, which in this case was a csv file, then transforming the data into a more usable form, and finally loading the data somewhere else.
#
# The purpose of ETL pipelines is to make data more usable and accessible.
