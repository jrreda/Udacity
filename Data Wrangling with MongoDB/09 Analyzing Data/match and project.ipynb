# %%
# #!/usr/bin/env python
# """
# Write an aggregation query to answer this question:

# Of the users in the "Brasilia" timezone who have tweeted 100 times or more,
# who has the largest number of followers?

# The following hints will help you solve this problem:
# - Time zone is found in the "time_zone" field of the user object in each tweet.
# - The number of tweets for each user is found in the "statuses_count" field.
#   To access these fields you will need to use dot notation (from Lesson 4)
# - Your aggregation query should return something like the following:
# {u'ok': 1.0,
#  u'result': [{u'_id': ObjectId('52fd2490bac3fa1975477702'),
#                   u'followers': 2597,
#                   u'screen_name': u'marbles',
#                   u'tweets': 12334}]}
# Note that you will need to create the fields 'followers', 'screen_name' and 'tweets'.

# Please modify only the 'make_pipeline' function so that it creates and returns an aggregation 
# pipeline that can be passed to the MongoDB aggregate function. As in our examples in this lesson,
# the aggregation pipeline should be a list of one or more dictionary objects. 
# Please review the lesson examples if you are unsure of the syntax.

# Your code will be run against a MongoDB instance that we have provided. If you want to run this code
# locally on your machine, you have to install MongoDB, download and insert the dataset.
# For instructions related to MongoDB setup and datasets please see Course Materials.

# Please note that the dataset you are using here is a smaller version of the twitter dataset used 
# in examples in this lesson. If you attempt some of the same queries that we looked at in the lesson 
# examples, your results will be different.
# """

# %%
from pymongo import MongoClient

client = MongoClient('localhost:27017')
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'udacity']

# %%
db = client.udacity

# %%
twitter = db.twitter

# %%
# Example Tweet:
from pprint import pprint

pprint(twitter.find_one())
# Out:
# {'_id': ObjectId('63e3b543beb9905c522e8828'),
#  'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Sep 02 18:11:23 +0000 2010',
#  'entities': {'hashtags': [], 'urls': [], 'user_mentions': []},
#  'favorited': False,
#  'geo': None,
#  'id': 22819396900,
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_user_id': None,
#  'place': None,
#  'retweet_count': None,
#  'retweeted': False,
#  'source': 'web',
#  'text': 'eu preciso de terminar de fazer a minha tabela, está muito foda **',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Jul 03 21:44:05 +0000 2009',
#           'description': 'só os loucos sabem (:',
#           'favourites_count': 1,
#           'follow_request_sent': None,
#           'followers_count': 102,
#           'following': None,
#           'friends_count': 73,
#           'geo_enabled': False,
#           'id': 53507833,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Beatriz Helena Cunha',
#           'notifications': None,
#           'profile_background_color': '081114',
#           'profile_background_image_url': 'http://a1.twimg.com/profile_background_images/133178546/biatwitter.jpg',
#           'profile_background_tile': True,
#           'profile_image_url': 'http://a2.twimg.com/profile_images/1036412454/OgAAADXK9q6kaxrvfwQTINH66RVLAH9YHb-veRTA4FaWb9KtbGGV_yKTGzmvzTfJidqAb5gK_mpspIE-MIvAASGH2CwAm1T1UIPQk0-HS8x_TV5kdnW30nch7ODk-1_normal.jpg',
#           'profile_link_color': 'eb55b6',
#           'profile_sidebar_border_color': '1c9dbd',
#           'profile_sidebar_fill_color': '768575',
#           'profile_text_color': '25b8c2',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'Bia_cunha1',
#           'show_all_inline_media': False,
#           'statuses_count': 3504,
#           'time_zone': 'Brasilia',
#           'url': 'http://http://www.orkut.com.br/Main#Profile?uid=1433295880233078770',
#           'utc_offset': -10800,
#           'verified': False}}

# %%
pipeline = [
    {'$match': {'user.time_zone': 'Brasilia',
                'user.statuses_count': {'$gte':100}}},
    {'$project': {'_id':'$_id',
                  'followers': '$user.followers_count',
                  'screen_name': '$user.screen_name',
                  'tweets': '$user.statuses_count'}},
    {'$sort': {'tweets': -1}}
]

# %%
for doc in twitter.aggregate(pipeline):
    pprint(doc)
# Out:
# {'_id': ObjectId('63e3b560beb9905c522f426a'),
#  'followers': 9062,
#  'screen_name': 'marcelobernard',
#  'tweets': 133098}
# {'_id': ObjectId('63e3b55ebeb9905c522f346b'),
#  'followers': 1861,
#  'screen_name': 'fuckyouvvmuch',
#  'tweets': 97234}
# {'_id': ObjectId('63e3b54bbeb9905c522ebe61'),
#  'followers': 2019,
#  'screen_name': 'amandaagarces',
#  'tweets': 87172}
# {'_id': ObjectId('63e3b55fbeb9905c522f3eab'),
#  'followers': 6546,
#  'screen_name': 'RadarBlitz',
#  'tweets': 80813}
# {'_id': ObjectId('63e3b54cbeb9905c522eca8f'),
#  'followers': 6543,
#  'screen_name': 'RadarBlitz',
#  'tweets': 80777}
# {'_id': ObjectId('63e3b54cbeb9905c522eca3c'),
#  'followers': 6543,
#  'screen_name': 'RadarBlitz',
#  'tweets': 80776}
# {'_id': ObjectId('63e3b54bbeb9905c522ec257'),
#  'followers': 54176,
#  'screen_name': 'CrisL',
#  'tweets': 78338}
# {'_id': ObjectId('63e3b54dbeb9905c522ecc1d'),
#  'followers': 3480,
#  'screen_name': 'martorelli',
#  'tweets': 72354}
# {'_id': ObjectId('63e3b54fbeb9905c522ed8b4'),
#  'followers': 3471,
#  'screen_name': 'V_inny',
#  'tweets': 70060}
# {'_id': ObjectId('63e3b549beb9905c522eb40f'),
#  'followers': 8198,
#  'screen_name': '_Raiiane_',
#  'tweets': 67365}
# {'_id': ObjectId('63e3b560beb9905c522f41b6'),
#  'followers': 226,
#  'screen_name': 'SegundoPlanoBR',
#  'tweets': 66591}
# {'_id': ObjectId('63e3b55abeb9905c522f1d82'),
#  'followers': 226,
#  'screen_name': 'SegundoPlanoBR',
#  'tweets': 66538}
# {'_id': ObjectId('63e3b559beb9905c522f1564'),
#  'followers': 226,
#  'screen_name': 'SegundoPlanoBR',
#  'tweets': 66520}
# {'_id': ObjectId('63e3b555beb9905c522f00e0'),
#  'followers': 3346,
#  'screen_name': 'm_maarcos',
#  'tweets': 64132}
# {'_id': ObjectId('63e3b55fbeb9905c522f3aba'),
#  'followers': 10754,
#  'screen_name': 'joaomernick13',
#  'tweets': 58216}
# {'_id': ObjectId('63e3b550beb9905c522edda4'),
#  'followers': 11817,
#  'screen_name': 'capettiinha',
#  'tweets': 57998}
# {'_id': ObjectId('63e3b55fbeb9905c522f3b91'),
#  'followers': 1060,
#  'screen_name': 'mipreterotti',
#  'tweets': 57383}
# {'_id': ObjectId('63e3b545beb9905c522e97f1'),
#  'followers': 2045,
#  'screen_name': 'TaniaClorofila',
#  'tweets': 52188}
# {'_id': ObjectId('63e3b55fbeb9905c522f3edd'),
#  'followers': 714,
#  'screen_name': 'nymphetagirl',
#  'tweets': 51883}
# {'_id': ObjectId('63e3b545beb9905c522e98be'),
#  'followers': 703,
#  'screen_name': 'AgenciaIN',
#  'tweets': 50191}
# {'_id': ObjectId('63e3b549beb9905c522eb329'),
#  'followers': 900,
#  'screen_name': 'marif_',
#  'tweets': 50088}
# {'_id': ObjectId('63e3b546beb9905c522e9ea8'),
#  'followers': 900,
#  'screen_name': 'marif_',
#  'tweets': 50073}
# {'_id': ObjectId('63e3b548beb9905c522eabb3'),
#  'followers': 891,
#  'screen_name': 'mah_portilla',
#  'tweets': 49511}
# {'_id': ObjectId('63e3b559beb9905c522f1623'),
#  'followers': 57774,
#  'screen_name': 'lepetitpromo',
#  'tweets': 49358}
# {'_id': ObjectId('63e3b54dbeb9905c522ecd6d'),
#  'followers': 21750,
#  'screen_name': 'caioscheleger',
#  'tweets': 47990}
# {'_id': ObjectId('63e3b55fbeb9905c522f3d83'),
#  'followers': 2222,
#  'screen_name': 'Divulgary',
#  'tweets': 44454}
# {'_id': ObjectId('63e3b54dbeb9905c522ed118'),
#  'followers': 16826,
#  'screen_name': 'JBieber4world',
#  'tweets': 44451}
# {'_id': ObjectId('63e3b559beb9905c522f17c2'),
#  'followers': 1929,
#  'screen_name': '_paradise',
#  'tweets': 43920}
# {'_id': ObjectId('63e3b55abeb9905c522f1e24'),
#  'followers': 336,
#  'screen_name': 'MangaratibaNews',
#  'tweets': 43835}
# {'_id': ObjectId('63e3b543beb9905c522e8e62'),
#  'followers': 336,
#  'screen_name': 'MangaratibaNews',
#  'tweets': 43814}
# {'_id': ObjectId('63e3b55ebeb9905c522f32cd'),
#  'followers': 819,
#  'screen_name': 'vanessa_geovana',
#  'tweets': 43397}
# {'_id': ObjectId('63e3b543beb9905c522e8c62'),
#  'followers': 819,
#  'screen_name': 'vanessa_geovana',
#  'tweets': 43348}
# {'_id': ObjectId('63e3b54cbeb9905c522ec8f2'),
#  'followers': 482,
#  'screen_name': 'annac182',
#  'tweets': 43260}
# {'_id': ObjectId('63e3b54bbeb9905c522ec270'),
#  'followers': 6183,
#  'screen_name': 'heyfabs_',
#  'tweets': 41715}
# {'_id': ObjectId('63e3b54abeb9905c522eb9a4'),
#  'followers': 316,
#  'screen_name': 'GT_Esportes',
#  'tweets': 41643}
# {'_id': ObjectId('63e3b561beb9905c522f4a41'),
#  'followers': 4600,
#  'screen_name': 'ArielGracelli',
#  'tweets': 41545}
# {'_id': ObjectId('63e3b55fbeb9905c522f38cc'),
#  'followers': 4601,
#  'screen_name': 'ArielGracelli',
#  'tweets': 41540}
# {'_id': ObjectId('63e3b551beb9905c522ee441'),
#  'followers': 718,
#  'screen_name': 'JonhMaster',
#  'tweets': 41227}
# {'_id': ObjectId('63e3b54dbeb9905c522ed170'),
#  'followers': 612,
#  'screen_name': 'FerFuturegirl',
#  'tweets': 40655}
# {'_id': ObjectId('63e3b547beb9905c522ea0f2'),
#  'followers': 2400,
#  'screen_name': 'jdariosjunior',
#  'tweets': 40130}
# {'_id': ObjectId('63e3b561beb9905c522f4980'),
#  'followers': 918,
#  'screen_name': 'GAPfurlan',
#  'tweets': 40029}
# {'_id': ObjectId('63e3b556beb9905c522f0286'),
#  'followers': 1651,
#  'screen_name': 'djmangueira',
#  'tweets': 39722}
# {'_id': ObjectId('63e3b554beb9905c522efc95'),
#  'followers': 1651,
#  'screen_name': 'djmangueira',
#  'tweets': 39721}
# {'_id': ObjectId('63e3b550beb9905c522edfa9'),
#  'followers': 1651,
#  'screen_name': 'djmangueira',
#  'tweets': 39713}
# {'_id': ObjectId('63e3b54abeb9905c522eb601'),
#  'followers': 1651,
#  'screen_name': 'djmangueira',
#  'tweets': 39708}
# {'_id': ObjectId('63e3b552beb9905c522eed3e'),
#  'followers': 8095,
#  'screen_name': 'FeliipeCF',
#  'tweets': 39402}
# {'_id': ObjectId('63e3b55abeb9905c522f1d39'),
#  'followers': 466,
#  'screen_name': 'FlaPompeu',
#  'tweets': 39007}
# {'_id': ObjectId('63e3b557beb9905c522f0922'),
#  'followers': 2147,
#  'screen_name': 'carolinamendes',
#  'tweets': 38739}
# {'_id': ObjectId('63e3b554beb9905c522efc4e'),
#  'followers': 273,
#  'screen_name': 'carlamaia',
#  'tweets': 38040}
# {'_id': ObjectId('63e3b54dbeb9905c522ecff8'),
#  'followers': 651,
#  'screen_name': 'heyitsdani',
#  'tweets': 37549}
# {'_id': ObjectId('63e3b545beb9905c522e9b69'),
#  'followers': 2891,
#  'screen_name': 'HospicioDoMcFLY',
#  'tweets': 37331}
# {'_id': ObjectId('63e3b548beb9905c522ea84d'),
#  'followers': 34384,
#  'screen_name': 'RamonBatista_',
#  'tweets': 37247}
# {'_id': ObjectId('63e3b554beb9905c522ef9d9'),
#  'followers': 2175,
#  'screen_name': 'vinnysacramento',
#  'tweets': 36764}
# {'_id': ObjectId('63e3b54dbeb9905c522ecd05'),
#  'followers': 593,
#  'screen_name': 'PaamSpunk',
#  'tweets': 36438}
# {'_id': ObjectId('63e3b54cbeb9905c522ec432'),
#  'followers': 593,
#  'screen_name': 'PaamSpunk',
#  'tweets': 36433}
# {'_id': ObjectId('63e3b54abeb9905c522eb5b2'),
#  'followers': 524,
#  'screen_name': 'thaah_toscano',
#  'tweets': 36250}
# {'_id': ObjectId('63e3b550beb9905c522edfb2'),
#  'followers': 530,
#  'screen_name': 'bruneves',
#  'tweets': 36138}
# {'_id': ObjectId('63e3b54abeb9905c522eb864'),
#  'followers': 1110,
#  'screen_name': 'mauzpensamentos',
#  'tweets': 35965}
# {'_id': ObjectId('63e3b55fbeb9905c522f3e97'),
#  'followers': 813,
#  'screen_name': 'mmelandgraf',
#  'tweets': 35615}
# {'_id': ObjectId('63e3b557beb9905c522f0c20'),
#  'followers': 30337,
#  'screen_name': 'JobinhoSouza',
#  'tweets': 35483}
# {'_id': ObjectId('63e3b547beb9905c522ea434'),
#  'followers': 1030,
#  'screen_name': 'julia_machado',
#  'tweets': 35465}
# {'_id': ObjectId('63e3b55fbeb9905c522f3c25'),
#  'followers': 342,
#  'screen_name': 'nataliaan',
#  'tweets': 35239}
# {'_id': ObjectId('63e3b557beb9905c522f0af8'),
#  'followers': 922,
#  'screen_name': 'CarlaCrisRose',
#  'tweets': 35189}
# {'_id': ObjectId('63e3b557beb9905c522f0b9b'),
#  'followers': 3376,
#  'screen_name': 'homensvaidosos',
#  'tweets': 35185}
# {'_id': ObjectId('63e3b553beb9905c522eef2e'),
#  'followers': 922,
#  'screen_name': 'CarlaCrisRose',
#  'tweets': 35181}
# {'_id': ObjectId('63e3b54dbeb9905c522ecee7'),
#  'followers': 3343,
#  'screen_name': 'luanbonin',
#  'tweets': 34731}
# {'_id': ObjectId('63e3b543beb9905c522e8b7a'),
#  'followers': 430,
#  'screen_name': 'silvita83',
#  'tweets': 34580}
# {'_id': ObjectId('63e3b547beb9905c522ea216'),
#  'followers': 1805,
#  'screen_name': 'danuzza',
#  'tweets': 33788}
# {'_id': ObjectId('63e3b559beb9905c522f17a7'),
#  'followers': 12827,
#  'screen_name': 'dankieer',
#  'tweets': 33085}
# {'_id': ObjectId('63e3b558beb9905c522f1001'),
#  'followers': 1669,
#  'screen_name': '_ItsLeonardo',
#  'tweets': 33031}
# {'_id': ObjectId('63e3b557beb9905c522f0bd7'),
#  'followers': 489,
#  'screen_name': 'withfeeling_',
#  'tweets': 32874}
# {'_id': ObjectId('63e3b549beb9905c522eb40c'),
#  'followers': 487,
#  'screen_name': 'withfeeling_',
#  'tweets': 32857}
# {'_id': ObjectId('63e3b55cbeb9905c522f254d'),
#  'followers': 141,
#  'screen_name': 'Felipe_Piethro',
#  'tweets': 32854}
# {'_id': ObjectId('63e3b557beb9905c522f0aca'),
#  'followers': 141,
#  'screen_name': 'Felipe_Piethro',
#  'tweets': 32850}
# {'_id': ObjectId('63e3b54fbeb9905c522ed78e'),
#  'followers': 141,
#  'screen_name': 'Felipe_Piethro',
#  'tweets': 32839}
# {'_id': ObjectId('63e3b544beb9905c522e91db'),
#  'followers': 141,
#  'screen_name': 'Felipe_Piethro',
#  'tweets': 32822}
# {'_id': ObjectId('63e3b546beb9905c522e9c3c'),
#  'followers': 324,
#  'screen_name': 'leozeballos',
#  'tweets': 32609}
# {'_id': ObjectId('63e3b55dbeb9905c522f2fde'),
#  'followers': 21527,
#  'screen_name': 'wloiola',
#  'tweets': 32600}
# {'_id': ObjectId('63e3b548beb9905c522ea927'),
#  'followers': 2987,
#  'screen_name': 'Gabes_nogueira',
#  'tweets': 32346}
# {'_id': ObjectId('63e3b545beb9905c522e95f7'),
#  'followers': 2980,
#  'screen_name': 'Gabes_nogueira',
#  'tweets': 32339}
# {'_id': ObjectId('63e3b546beb9905c522e9bbc'),
#  'followers': 2173,
#  'screen_name': 'Fatimatozzi',
#  'tweets': 31700}
# {'_id': ObjectId('63e3b55cbeb9905c522f25f9'),
#  'followers': 23116,
#  'screen_name': 'lh_sucesso',
#  'tweets': 31690}
# {'_id': ObjectId('63e3b556beb9905c522f06b8'),
#  'followers': 609,
#  'screen_name': 'judelawrosa',
#  'tweets': 31624}
# {'_id': ObjectId('63e3b547beb9905c522ea0f1'),
#  'followers': 639,
#  'screen_name': 'icompleteyou',
#  'tweets': 31527}
# {'_id': ObjectId('63e3b55ebeb9905c522f3624'),
#  'followers': 594,
#  'screen_name': 'brunadiass',
#  'tweets': 31435}
# {'_id': ObjectId('63e3b55ebeb9905c522f35e8'),
#  'followers': 594,
#  'screen_name': 'brunadiass',
#  'tweets': 31434}
# {'_id': ObjectId('63e3b54abeb9905c522eb46a'),
#  'followers': 148,
#  'screen_name': 'Diego_Amaral01',
#  'tweets': 31398}
# {'_id': ObjectId('63e3b553beb9905c522ef1b8'),
#  'followers': 213,
#  'screen_name': 'LeleFigueiredo',
#  'tweets': 30845}
# {'_id': ObjectId('63e3b55abeb9905c522f18f0'),
#  'followers': 371,
#  'screen_name': 'juycer',
#  'tweets': 30512}
# {'_id': ObjectId('63e3b548beb9905c522eae49'),
#  'followers': 1123,
#  'screen_name': 'kizuu',
#  'tweets': 30452}
# {'_id': ObjectId('63e3b551beb9905c522ee91a'),
#  'followers': 950,
#  'screen_name': 'ItsAmandaC',
#  'tweets': 30226}
# {'_id': ObjectId('63e3b547beb9905c522ea6c6'),
#  'followers': 2277,
#  'screen_name': 'Dedois',
#  'tweets': 30116}
# {'_id': ObjectId('63e3b54fbeb9905c522edb6f'),
#  'followers': 498,
#  'screen_name': 'flavianalin',
#  'tweets': 30094}
# {'_id': ObjectId('63e3b55cbeb9905c522f248f'),
#  'followers': 2168,
#  'screen_name': 'vyktorb',
#  'tweets': 29701}
# {'_id': ObjectId('63e3b54cbeb9905c522ec4bc'),
#  'followers': 1028,
#  'screen_name': 'RapaduraMan',
#  'tweets': 29058}
# {'_id': ObjectId('63e3b55bbeb9905c522f1f54'),
#  'followers': 1435,
#  'screen_name': 'littlemay_',
#  'tweets': 28904}
# {'_id': ObjectId('63e3b554beb9905c522ef98e'),
#  'followers': 13176,
#  'screen_name': 'JorginhoDutra',
#  'tweets': 28654}
# {'_id': ObjectId('63e3b562beb9905c522f4ca2'),
#  'followers': 817,
#  'screen_name': 'alinebicudo',
#  'tweets': 28535}
# {'_id': ObjectId('63e3b54fbeb9905c522eda55'),
#  'followers': 28159,
#  'screen_name': 'MarianaBelem',
#  'tweets': 28505}
# {'_id': ObjectId('63e3b545beb9905c522e9561'),
#  'followers': 4507,
#  'screen_name': 'correio_dopovo',
#  'tweets': 28135}
# {'_id': ObjectId('63e3b543beb9905c522e888c'),
#  'followers': 275,
#  'screen_name': 'caaio_m',
#  'tweets': 27980}
# {'_id': ObjectId('63e3b553beb9905c522ef12e'),
#  'followers': 624,
#  'screen_name': 'ClauHerreira',
#  'tweets': 27980}
# {'_id': ObjectId('63e3b560beb9905c522f4358'),
#  'followers': 1001,
#  'screen_name': 'KaiqueAguiar',
#  'tweets': 27872}
# {'_id': ObjectId('63e3b549beb9905c522eb3c9'),
#  'followers': 341,
#  'screen_name': 'dessalsilva',
#  'tweets': 27851}
# {'_id': ObjectId('63e3b548beb9905c522eaf26'),
#  'followers': 1416,
#  'screen_name': 'bluekakazitcha',
#  'tweets': 27688}
# {'_id': ObjectId('63e3b554beb9905c522ef5c9'),
#  'followers': 915,
#  'screen_name': 'marichagas',
#  'tweets': 27559}
# {'_id': ObjectId('63e3b54cbeb9905c522eca2c'),
#  'followers': 914,
#  'screen_name': 'marichagas',
#  'tweets': 27545}
# {'_id': ObjectId('63e3b556beb9905c522f04d1'),
#  'followers': 1765,
#  'screen_name': 'jkennis3POV',
#  'tweets': 27539}
# {'_id': ObjectId('63e3b553beb9905c522ef1d8'),
#  'followers': 4681,
#  'screen_name': 'ThiagoTG',
#  'tweets': 27524}
# {'_id': ObjectId('63e3b562beb9905c522f4f8b'),
#  'followers': 362,
#  'screen_name': 'PaulaKotouc',
#  'tweets': 27124}
# {'_id': ObjectId('63e3b55fbeb9905c522f3f0e'),
#  'followers': 2339,
#  'screen_name': 'priduarte_',
#  'tweets': 27055}
# {'_id': ObjectId('63e3b55dbeb9905c522f2f0a'),
#  'followers': 486,
#  'screen_name': 'mathsupimpa',
#  'tweets': 26930}
# {'_id': ObjectId('63e3b561beb9905c522f4712'),
#  'followers': 1137,
#  'screen_name': 'biafacchini',
#  'tweets': 26730}
# {'_id': ObjectId('63e3b54bbeb9905c522ebeaf'),
#  'followers': 90,
#  'screen_name': 'vinicius_barros',
#  'tweets': 26673}
# {'_id': ObjectId('63e3b561beb9905c522f473f'),
#  'followers': 138,
#  'screen_name': 'VeraMed',
#  'tweets': 26624}
# {'_id': ObjectId('63e3b556beb9905c522f0341'),
#  'followers': 3993,
#  'screen_name': 'oraporra',
#  'tweets': 26613}
# {'_id': ObjectId('63e3b54cbeb9905c522ec666'),
#  'followers': 138,
#  'screen_name': 'VeraMed',
#  'tweets': 26611}
# {'_id': ObjectId('63e3b54cbeb9905c522ec47a'),
#  'followers': 8621,
#  'screen_name': 'gadamous',
#  'tweets': 26395}
# {'_id': ObjectId('63e3b54cbeb9905c522eca88'),
#  'followers': 2776,
#  'screen_name': 'paulojornalist',
#  'tweets': 26311}
# {'_id': ObjectId('63e3b55bbeb9905c522f1ec3'),
#  'followers': 346,
#  'screen_name': 'LottaNerve',
#  'tweets': 26152}
# {'_id': ObjectId('63e3b55fbeb9905c522f3c03'),
#  'followers': 4430,
#  'screen_name': 'MarbiaFernandes',
#  'tweets': 26141}
# {'_id': ObjectId('63e3b558beb9905c522f1232'),
#  'followers': 471,
#  'screen_name': 'mandsrawr',
#  'tweets': 26089}
# {'_id': ObjectId('63e3b54dbeb9905c522ecf78'),
#  'followers': 463,
#  'screen_name': 'anaschwarzz',
#  'tweets': 26038}
# {'_id': ObjectId('63e3b54cbeb9905c522ec436'),
#  'followers': 284,
#  'screen_name': 'FeelingSorry_',
#  'tweets': 25652}
# {'_id': ObjectId('63e3b54fbeb9905c522ed7aa'),
#  'followers': 1535,
#  'screen_name': 'LarissaSODMG',
#  'tweets': 25632}
# {'_id': ObjectId('63e3b55ebeb9905c522f32e5'),
#  'followers': 626,
#  'screen_name': 'Cleocelio',
#  'tweets': 25562}
# {'_id': ObjectId('63e3b543beb9905c522e8ccf'),
#  'followers': 626,
#  'screen_name': 'Cleocelio',
#  'tweets': 25549}
# {'_id': ObjectId('63e3b55abeb9905c522f1d67'),
#  'followers': 424,
#  'screen_name': 'luavelloso',
#  'tweets': 25498}
# {'_id': ObjectId('63e3b555beb9905c522f00ec'),
#  'followers': 241,
#  'screen_name': 'vickunleashed',
#  'tweets': 25416}
# {'_id': ObjectId('63e3b55ebeb9905c522f35db'),
#  'followers': 180,
#  'screen_name': 'neiciccone',
#  'tweets': 25351}
# {'_id': ObjectId('63e3b558beb9905c522f0f18'),
#  'followers': 4861,
#  'screen_name': 'onlylovato',
#  'tweets': 25136}
# {'_id': ObjectId('63e3b549beb9905c522eb079'),
#  'followers': 539,
#  'screen_name': 'x_duuh',
#  'tweets': 25024}
# {'_id': ObjectId('63e3b55fbeb9905c522f3988'),
#  'followers': 1817,
#  'screen_name': 'lucastar07',
#  'tweets': 24922}
# {'_id': ObjectId('63e3b548beb9905c522eadb4'),
#  'followers': 866,
#  'screen_name': 'dieluge',
#  'tweets': 24917}
# {'_id': ObjectId('63e3b55ebeb9905c522f30dc'),
#  'followers': 44695,
#  'screen_name': 'Leonardo_sk8',
#  'tweets': 24898}
# {'_id': ObjectId('63e3b550beb9905c522ee129'),
#  'followers': 444,
#  'screen_name': 'mooglez',
#  'tweets': 24873}
# {'_id': ObjectId('63e3b559beb9905c522f1659'),
#  'followers': 2038,
#  'screen_name': 'lala_araujo',
#  'tweets': 24825}
# {'_id': ObjectId('63e3b546beb9905c522e9eee'),
#  'followers': 167,
#  'screen_name': 'georgeaugusto1',
#  'tweets': 24747}
# {'_id': ObjectId('63e3b557beb9905c522f0b4c'),
#  'followers': 285,
#  'screen_name': 'camikz',
#  'tweets': 24715}
# {'_id': ObjectId('63e3b54ebeb9905c522ed461'),
#  'followers': 284,
#  'screen_name': 'camikz',
#  'tweets': 24699}
# {'_id': ObjectId('63e3b55ebeb9905c522f37d4'),
#  'followers': 398,
#  'screen_name': 'anaabanana',
#  'tweets': 24672}
# {'_id': ObjectId('63e3b554beb9905c522efc4b'),
#  'followers': 883,
#  'screen_name': 'lidiazuin',
#  'tweets': 24592}
# {'_id': ObjectId('63e3b545beb9905c522e97bd'),
#  'followers': 299,
#  'screen_name': 'CiciSpunk',
#  'tweets': 24509}
# {'_id': ObjectId('63e3b554beb9905c522ef99e'),
#  'followers': 1572,
#  'screen_name': 'herlenesantos',
#  'tweets': 24505}
# {'_id': ObjectId('63e3b561beb9905c522f45cf'),
#  'followers': 471,
#  'screen_name': 'whatsupleticia',
#  'tweets': 24473}
# {'_id': ObjectId('63e3b561beb9905c522f466b'),
#  'followers': 813,
#  'screen_name': 'lilaise',
#  'tweets': 24379}
# {'_id': ObjectId('63e3b55bbeb9905c522f227b'),
#  'followers': 600,
#  'screen_name': 'guisavinon',
#  'tweets': 24287}
# {'_id': ObjectId('63e3b557beb9905c522f09c1'),
#  'followers': 600,
#  'screen_name': 'guisavinon',
#  'tweets': 24282}
# {'_id': ObjectId('63e3b547beb9905c522ea10c'),
#  'followers': 249,
#  'screen_name': 'bia_dempeo',
#  'tweets': 24238}
# {'_id': ObjectId('63e3b555beb9905c522efe9e'),
#  'followers': 320,
#  'screen_name': 'mari_t1',
#  'tweets': 24222}
# {'_id': ObjectId('63e3b547beb9905c522ea261'),
#  'followers': 332,
#  'screen_name': 'giiusantiago',
#  'tweets': 24203}
# {'_id': ObjectId('63e3b55fbeb9905c522f3c89'),
#  'followers': 1031,
#  'screen_name': 'anaritti',
#  'tweets': 24129}
# {'_id': ObjectId('63e3b54dbeb9905c522ed14d'),
#  'followers': 350,
#  'screen_name': 'GiBronze',
#  'tweets': 23958}
# {'_id': ObjectId('63e3b55cbeb9905c522f2492'),
#  'followers': 740,
#  'screen_name': 'elimafra',
#  'tweets': 23957}
# {'_id': ObjectId('63e3b543beb9905c522e8dd4'),
#  'followers': 133,
#  'screen_name': 'Kandyland__',
#  'tweets': 23907}
# {'_id': ObjectId('63e3b553beb9905c522eef85'),
#  'followers': 4759,
#  'screen_name': 'LuisJunior_',
#  'tweets': 23907}
# {'_id': ObjectId('63e3b543beb9905c522e884e'),
#  'followers': 381,
#  'screen_name': 'underherskin_',
#  'tweets': 23890}
# {'_id': ObjectId('63e3b54abeb9905c522eb713'),
#  'followers': 357,
#  'screen_name': 'mariipeduti',
#  'tweets': 23884}
# {'_id': ObjectId('63e3b549beb9905c522eb32a'),
#  'followers': 357,
#  'screen_name': 'mariipeduti',
#  'tweets': 23881}
# {'_id': ObjectId('63e3b55dbeb9905c522f2ede'),
#  'followers': 743,
#  'screen_name': 'JuuOliveiira',
#  'tweets': 23798}
# {'_id': ObjectId('63e3b55dbeb9905c522f2e40'),
#  'followers': 143,
#  'screen_name': 'Tkn117',
#  'tweets': 23713}
# {'_id': ObjectId('63e3b54fbeb9905c522edcda'),
#  'followers': 539,
#  'screen_name': 'ramiro120',
#  'tweets': 23660}
# {'_id': ObjectId('63e3b54bbeb9905c522ebc82'),
#  'followers': 40600,
#  'screen_name': 'BiebsAddiction',
#  'tweets': 23600}
# {'_id': ObjectId('63e3b55fbeb9905c522f38cf'),
#  'followers': 614,
#  'screen_name': 'TalktoMat',
#  'tweets': 23563}
# {'_id': ObjectId('63e3b543beb9905c522e88e8'),
#  'followers': 927,
#  'screen_name': 'nataliabittar',
#  'tweets': 23551}
# {'_id': ObjectId('63e3b545beb9905c522e956d'),
#  'followers': 924,
#  'screen_name': 'Rayssavalerio',
#  'tweets': 23546}
# {'_id': ObjectId('63e3b55dbeb9905c522f2c8b'),
#  'followers': 1532,
#  'screen_name': 'Leeow_',
#  'tweets': 23502}
# {'_id': ObjectId('63e3b562beb9905c522f4d22'),
#  'followers': 416,
#  'screen_name': 'marimayumi',
#  'tweets': 23478}
# {'_id': ObjectId('63e3b556beb9905c522f0241'),
#  'followers': 443,
#  'screen_name': 'Laisalves',
#  'tweets': 23375}
# {'_id': ObjectId('63e3b54cbeb9905c522ec5ff'),
#  'followers': 526,
#  'screen_name': 'yaaara_a',
#  'tweets': 23369}
# {'_id': ObjectId('63e3b55fbeb9905c522f382f'),
#  'followers': 301,
#  'screen_name': 'YarthoX',
#  'tweets': 23210}
# {'_id': ObjectId('63e3b54ebeb9905c522ed37f'),
#  'followers': 1002,
#  'screen_name': 'SoNotSexy',
#  'tweets': 23207}
# {'_id': ObjectId('63e3b544beb9905c522e9260'),
#  'followers': 417,
#  'screen_name': 'rafarafes',
#  'tweets': 23050}
# {'_id': ObjectId('63e3b55fbeb9905c522f39ea'),
#  'followers': 629,
#  'screen_name': 'Juan_Alves',
#  'tweets': 22972}
# {'_id': ObjectId('63e3b55bbeb9905c522f22d1'),
#  'followers': 1253,
#  'screen_name': 'SteeGimenes',
#  'tweets': 22794}
# {'_id': ObjectId('63e3b553beb9905c522ef1e1'),
#  'followers': 381,
#  'screen_name': 'nathsimaroli',
#  'tweets': 22683}
# {'_id': ObjectId('63e3b562beb9905c522f4ccf'),
#  'followers': 2054,
#  'screen_name': 'danilo_power',
#  'tweets': 22672}
# {'_id': ObjectId('63e3b55bbeb9905c522f22c1'),
#  'followers': 15224,
#  'screen_name': 'UOLNoticias',
#  'tweets': 22541}
# {'_id': ObjectId('63e3b54ebeb9905c522ed4c7'),
#  'followers': 244,
#  'screen_name': 'adalchic',
#  'tweets': 22523}
# {'_id': ObjectId('63e3b55cbeb9905c522f2947'),
#  'followers': 2049,
#  'screen_name': 'cidadeverde',
#  'tweets': 22460}
# {'_id': ObjectId('63e3b553beb9905c522eef09'),
#  'followers': 3972,
#  'screen_name': 'dannribeiro',
#  'tweets': 22431}
# {'_id': ObjectId('63e3b545beb9905c522e99c7'),
#  'followers': 696,
#  'screen_name': 'SueSouza',
#  'tweets': 22311}
# {'_id': ObjectId('63e3b55abeb9905c522f1ccd'),
#  'followers': 182,
#  'screen_name': 'x_talita_x',
#  'tweets': 22293}
# {'_id': ObjectId('63e3b554beb9905c522ef589'),
#  'followers': 182,
#  'screen_name': 'x_talita_x',
#  'tweets': 22275}
# {'_id': ObjectId('63e3b560beb9905c522f4257'),
#  'followers': 577,
#  'screen_name': 'whosthanny',
#  'tweets': 22250}
# {'_id': ObjectId('63e3b54bbeb9905c522ebd88'),
#  'followers': 1789,
#  'screen_name': 'JonasFansBr',
#  'tweets': 22163}
# {'_id': ObjectId('63e3b55cbeb9905c522f2646'),
#  'followers': 851,
#  'screen_name': 'Isabellam_',
#  'tweets': 22147}
# {'_id': ObjectId('63e3b560beb9905c522f409b'),
#  'followers': 418,
#  'screen_name': 'caiowned',
#  'tweets': 22087}
# {'_id': ObjectId('63e3b55abeb9905c522f1c25'),
#  'followers': 2576,
#  'screen_name': 'wtfblack',
#  'tweets': 22085}
# {'_id': ObjectId('63e3b549beb9905c522eb3f4'),
#  'followers': 1246,
#  'screen_name': 'maarianne',
#  'tweets': 22055}
# {'_id': ObjectId('63e3b557beb9905c522f0b5e'),
#  'followers': 689,
#  'screen_name': 'CaioCorraini',
#  'tweets': 21975}
# {'_id': ObjectId('63e3b54abeb9905c522ebac0'),
#  'followers': 510,
#  'screen_name': 'nickyes',
#  'tweets': 21931}
# {'_id': ObjectId('63e3b556beb9905c522f05c0'),
#  'followers': 173,
#  'screen_name': 'annytavares',
#  'tweets': 21909}
# {'_id': ObjectId('63e3b55bbeb9905c522f1f87'),
#  'followers': 420,
#  'screen_name': 'fabiolabr',
#  'tweets': 21814}
# {'_id': ObjectId('63e3b561beb9905c522f49b3'),
#  'followers': 97,
#  'screen_name': 'voaao',
#  'tweets': 21699}
# {'_id': ObjectId('63e3b548beb9905c522ea9dc'),
#  'followers': 354,
#  'screen_name': 'PaulPant',
#  'tweets': 21513}
# {'_id': ObjectId('63e3b547beb9905c522ea588'),
#  'followers': 3431,
#  'screen_name': 'amanda_jg',
#  'tweets': 21497}
# {'_id': ObjectId('63e3b54fbeb9905c522edb39'),
#  'followers': 572,
#  'screen_name': 'eriichenrique',
#  'tweets': 21443}
# {'_id': ObjectId('63e3b55abeb9905c522f1cc7'),
#  'followers': 277,
#  'screen_name': 'kikadelpiero',
#  'tweets': 21356}
# {'_id': ObjectId('63e3b553beb9905c522ef1a1'),
#  'followers': 438,
#  'screen_name': 'nandomayfair',
#  'tweets': 21297}
# {'_id': ObjectId('63e3b55cbeb9905c522f2a37'),
#  'followers': 320,
#  'screen_name': 'krolina17',
#  'tweets': 21253}
# {'_id': ObjectId('63e3b55cbeb9905c522f27e5'),
#  'followers': 3054,
#  'screen_name': 'Claudio108',
#  'tweets': 21215}
# {'_id': ObjectId('63e3b55abeb9905c522f1bc3'),
#  'followers': 2911,
#  'screen_name': 'ateucristao',
#  'tweets': 21116}
# {'_id': ObjectId('63e3b550beb9905c522ee031'),
#  'followers': 2907,
#  'screen_name': 'ateucristao',
#  'tweets': 21110}
# {'_id': ObjectId('63e3b54abeb9905c522eb4da'),
#  'followers': 2566,
#  'screen_name': 'DemiForever_s2',
#  'tweets': 21086}
# {'_id': ObjectId('63e3b551beb9905c522ee572'),
#  'followers': 233,
#  'screen_name': 'viata',
#  'tweets': 21047}
# {'_id': ObjectId('63e3b553beb9905c522eeee4'),
#  'followers': 1543,
#  'screen_name': 'fanningsupport',
#  'tweets': 21006}
# {'_id': ObjectId('63e3b55abeb9905c522f1bf1'),
#  'followers': 6327,
#  'screen_name': 'RestartMeuCeu',
#  'tweets': 20885}
# {'_id': ObjectId('63e3b558beb9905c522f1275'),
#  'followers': 6327,
#  'screen_name': 'RestartMeuCeu',
#  'tweets': 20879}
# {'_id': ObjectId('63e3b543beb9905c522e8843'),
#  'followers': 714,
#  'screen_name': 'samdrade',
#  'tweets': 20863}
# {'_id': ObjectId('63e3b553beb9905c522ef499'),
#  'followers': 304,
#  'screen_name': 'allaboutbia_',
#  'tweets': 20785}
# {'_id': ObjectId('63e3b558beb9905c522f138f'),
#  'followers': 1416,
#  'screen_name': 'leonylima',
#  'tweets': 20766}
# {'_id': ObjectId('63e3b55fbeb9905c522f3b29'),
#  'followers': 365,
#  'screen_name': 'analuizabueno',
#  'tweets': 20736}
# {'_id': ObjectId('63e3b557beb9905c522f0cc2'),
#  'followers': 297,
#  'screen_name': 'xbixxo',
#  'tweets': 20697}
# {'_id': ObjectId('63e3b54bbeb9905c522ec0fd'),
#  'followers': 297,
#  'screen_name': 'xbixxo',
#  'tweets': 20681}
# {'_id': ObjectId('63e3b54abeb9905c522eb9f1'),
#  'followers': 262,
#  'screen_name': 'Fla182',
#  'tweets': 20667}
# {'_id': ObjectId('63e3b553beb9905c522eee6e'),
#  'followers': 294,
#  'screen_name': 'enig_mah',
#  'tweets': 20624}
# {'_id': ObjectId('63e3b560beb9905c522f40c6'),
#  'followers': 3276,
#  'screen_name': 'pejulio',
#  'tweets': 20618}
# {'_id': ObjectId('63e3b555beb9905c522f0060'),
#  'followers': 1150,
#  'screen_name': 'kamms_',
#  'tweets': 20350}
# {'_id': ObjectId('63e3b55ebeb9905c522f35ba'),
#  'followers': 1921,
#  'screen_name': 'loosho',
#  'tweets': 20314}
# {'_id': ObjectId('63e3b545beb9905c522e97c2'),
#  'followers': 1016,
#  'screen_name': 'nandamedeiros_',
#  'tweets': 20217}
# {'_id': ObjectId('63e3b549beb9905c522eb09d'),
#  'followers': 522,
#  'screen_name': 'samukaonline',
#  'tweets': 20176}
# {'_id': ObjectId('63e3b554beb9905c522efac2'),
#  'followers': 917,
#  'screen_name': 'larissavip2',
#  'tweets': 20097}
# {'_id': ObjectId('63e3b544beb9905c522e933e'),
#  'followers': 780,
#  'screen_name': 'boooora',
#  'tweets': 20085}
# {'_id': ObjectId('63e3b55fbeb9905c522f3902'),
#  'followers': 1793,
#  'screen_name': '_cinetics',
#  'tweets': 20047}
# {'_id': ObjectId('63e3b549beb9905c522eaf67'),
#  'followers': 7968,
#  'screen_name': 'Gusttavomaia',
#  'tweets': 20032}
# {'_id': ObjectId('63e3b560beb9905c522f439d'),
#  'followers': 197,
#  'screen_name': 'Taty_Ferreira',
#  'tweets': 19970}
# {'_id': ObjectId('63e3b543beb9905c522e8aa2'),
#  'followers': 270,
#  'screen_name': 'dance_monkey',
#  'tweets': 19949}
# {'_id': ObjectId('63e3b556beb9905c522f050f'),
#  'followers': 197,
#  'screen_name': 'Taty_Ferreira',
#  'tweets': 19945}
# {'_id': ObjectId('63e3b55cbeb9905c522f24b1'),
#  'followers': 6572,
#  'screen_name': 'NatyDeep',
#  'tweets': 19892}
# {'_id': ObjectId('63e3b544beb9905c522e92cb'),
#  'followers': 2904,
#  'screen_name': 'atribunasantos',
#  'tweets': 19878}
# {'_id': ObjectId('63e3b558beb9905c522f0db2'),
#  'followers': 10604,
#  'screen_name': 'GabrielFerianii',
#  'tweets': 19789}
# {'_id': ObjectId('63e3b55abeb9905c522f1baf'),
#  'followers': 499,
#  'screen_name': 'BeaSantissta',
#  'tweets': 19693}
# {'_id': ObjectId('63e3b555beb9905c522efe50'),
#  'followers': 923,
#  'screen_name': 'Fkstew',
#  'tweets': 19593}
# {'_id': ObjectId('63e3b545beb9905c522e9af5'),
#  'followers': 975,
#  'screen_name': 'brumorango',
#  'tweets': 19387}
# {'_id': ObjectId('63e3b55bbeb9905c522f1fdb'),
#  'followers': 1178,
#  'screen_name': 'brunaufrj',
#  'tweets': 19282}
# {'_id': ObjectId('63e3b548beb9905c522ea7ba'),
#  'followers': 424,
#  'screen_name': 'ladyribeiro',
#  'tweets': 19241}
# {'_id': ObjectId('63e3b562beb9905c522f4cdc'),
#  'followers': 1027,
#  'screen_name': 'brendadawson',
#  'tweets': 19208}
# {'_id': ObjectId('63e3b54dbeb9905c522ecc11'),
#  'followers': 2320,
#  'screen_name': 'LauraCarpes',
#  'tweets': 19166}
# {'_id': ObjectId('63e3b547beb9905c522ea672'),
#  'followers': 869,
#  'screen_name': 'rubialtoebjk',
#  'tweets': 19063}
# {'_id': ObjectId('63e3b552beb9905c522eeaab'),
#  'followers': 1365,
#  'screen_name': 'LariCFC',
#  'tweets': 19041}
# {'_id': ObjectId('63e3b543beb9905c522e8a57'),
#  'followers': 334,
#  'screen_name': 'burnermanx',
#  'tweets': 19019}
# {'_id': ObjectId('63e3b554beb9905c522ef69e'),
#  'followers': 2935,
#  'screen_name': 'Gabriel_Rota',
#  'tweets': 19003}
# {'_id': ObjectId('63e3b558beb9905c522f0e24'),
#  'followers': 479,
#  'screen_name': 'wesleycota',
#  'tweets': 18968}
# {'_id': ObjectId('63e3b54dbeb9905c522ecefe'),
#  'followers': 464,
#  'screen_name': 'LucasCarralas',
#  'tweets': 18957}
# {'_id': ObjectId('63e3b55bbeb9905c522f22ee'),
#  'followers': 136,
#  'screen_name': 'heycupid_',
#  'tweets': 18862}
# {'_id': ObjectId('63e3b54abeb9905c522eb95e'),
#  'followers': 265,
#  'screen_name': '_liviaalonso',
#  'tweets': 18819}
# {'_id': ObjectId('63e3b561beb9905c522f45a3'),
#  'followers': 1844,
#  'screen_name': 'DuBehling',
#  'tweets': 18814}
# {'_id': ObjectId('63e3b551beb9905c522ee3c1'),
#  'followers': 485,
#  'screen_name': 'georgelemos1986',
#  'tweets': 18795}
# {'_id': ObjectId('63e3b552beb9905c522eebdc'),
#  'followers': 722,
#  'screen_name': 'gkhudson',
#  'tweets': 18664}
# {'_id': ObjectId('63e3b54ebeb9905c522ed63c'),
#  'followers': 583,
#  'screen_name': 'ohsoju',
#  'tweets': 18639}
# {'_id': ObjectId('63e3b555beb9905c522efea7'),
#  'followers': 117,
#  'screen_name': 'janeazevedo',
#  'tweets': 18541}
# {'_id': ObjectId('63e3b54ebeb9905c522ed362'),
#  'followers': 1834,
#  'screen_name': 'leonardopote',
#  'tweets': 18485}
# {'_id': ObjectId('63e3b54fbeb9905c522ed71d'),
#  'followers': 2087,
#  'screen_name': 'nik_bermudas6',
#  'tweets': 18321}
# {'_id': ObjectId('63e3b54ebeb9905c522ed584'),
#  'followers': 430,
#  'screen_name': 'sheilalves',
#  'tweets': 18230}
# {'_id': ObjectId('63e3b543beb9905c522e8b0b'),
#  'followers': 429,
#  'screen_name': 'sheilalves',
#  'tweets': 18206}
# {'_id': ObjectId('63e3b54cbeb9905c522ec964'),
#  'followers': 1075,
#  'screen_name': 'leonardude',
#  'tweets': 18146}
# {'_id': ObjectId('63e3b54fbeb9905c522edcf1'),
#  'followers': 1104,
#  'screen_name': 'ThayaneCamargo',
#  'tweets': 18017}
# {'_id': ObjectId('63e3b55dbeb9905c522f2da7'),
#  'followers': 20716,
#  'screen_name': 'kastanho',
#  'tweets': 17964}
# {'_id': ObjectId('63e3b552beb9905c522eeb64'),
#  'followers': 1655,
#  'screen_name': 'BurakoNego',
#  'tweets': 17951}
# {'_id': ObjectId('63e3b544beb9905c522e90fd'),
#  'followers': 1102,
#  'screen_name': 'bruxaooo',
#  'tweets': 17918}
# {'_id': ObjectId('63e3b553beb9905c522ef1ea'),
#  'followers': 487,
#  'screen_name': 'nafernandes13',
#  'tweets': 17851}
# {'_id': ObjectId('63e3b55cbeb9905c522f2b9f'),
#  'followers': 4414,
#  'screen_name': 'Kiinha_s',
#  'tweets': 17769}
# {'_id': ObjectId('63e3b550beb9905c522edf49'),
#  'followers': 319,
#  'screen_name': 'im_Bella_',
#  'tweets': 17717}
# {'_id': ObjectId('63e3b549beb9905c522eaf62'),
#  'followers': 339,
#  'screen_name': 'pskeitor',
#  'tweets': 17677}
# {'_id': ObjectId('63e3b558beb9905c522f1310'),
#  'followers': 283,
#  'screen_name': 'ayumichan',
#  'tweets': 17651}
# {'_id': ObjectId('63e3b55abeb9905c522f1c56'),
#  'followers': 1207,
#  'screen_name': 'TrevorKenskevyz',
#  'tweets': 17637}
# {'_id': ObjectId('63e3b54cbeb9905c522ec385'),
#  'followers': 1207,
#  'screen_name': 'TrevorKenskevyz',
#  'tweets': 17627}
# {'_id': ObjectId('63e3b555beb9905c522efd66'),
#  'followers': 11269,
#  'screen_name': 'portalUOL',
#  'tweets': 17511}
# {'_id': ObjectId('63e3b548beb9905c522eaa7c'),
#  'followers': 15227,
#  'screen_name': 'Julio_Valentim',
#  'tweets': 17438}
# {'_id': ObjectId('63e3b548beb9905c522eae86'),
#  'followers': 14200,
#  'screen_name': 'alesie',
#  'tweets': 17421}
# {'_id': ObjectId('63e3b547beb9905c522ea233'),
#  'followers': 178,
#  'screen_name': 'Jubiracs',
#  'tweets': 17401}
# {'_id': ObjectId('63e3b54dbeb9905c522ece21'),
#  'followers': 827,
#  'screen_name': 'henriqueguzella',
#  'tweets': 17388}
# {'_id': ObjectId('63e3b55fbeb9905c522f38d4'),
#  'followers': 7363,
#  'screen_name': 'SempreColorido',
#  'tweets': 17341}
# {'_id': ObjectId('63e3b55dbeb9905c522f2fd5'),
#  'followers': 1252,
#  'screen_name': 'RehSessa',
#  'tweets': 17304}
# {'_id': ObjectId('63e3b54abeb9905c522eb8e4'),
#  'followers': 201,
#  'screen_name': 'lana_fuchs',
#  'tweets': 17173}
# {'_id': ObjectId('63e3b549beb9905c522eaf3d'),
#  'followers': 468,
#  'screen_name': 'lucasportal',
#  'tweets': 17138}
# {'_id': ObjectId('63e3b54abeb9905c522eb7e1'),
#  'followers': 3922,
#  'screen_name': 'AderaldoNeto_',
#  'tweets': 16925}
# {'_id': ObjectId('63e3b55cbeb9905c522f2ad3'),
#  'followers': 8854,
#  'screen_name': 'youmakemesohot_',
#  'tweets': 16918}
# {'_id': ObjectId('63e3b546beb9905c522e9c36'),
#  'followers': 248,
#  'screen_name': 'DiiiRodriigues',
#  'tweets': 16908}
# {'_id': ObjectId('63e3b543beb9905c522e8f88'),
#  'followers': 3316,
#  'screen_name': 's1mone',
#  'tweets': 16855}
# {'_id': ObjectId('63e3b543beb9905c522e8f2d'),
#  'followers': 4944,
#  'screen_name': 'tonfletcher',
#  'tweets': 16840}
# {'_id': ObjectId('63e3b54dbeb9905c522ecf9a'),
#  'followers': 960,
#  'screen_name': 'eduardoduccigne',
#  'tweets': 16780}
# {'_id': ObjectId('63e3b54cbeb9905c522ec447'),
#  'followers': 7133,
#  'screen_name': 'marcelohk',
#  'tweets': 16777}
# {'_id': ObjectId('63e3b54bbeb9905c522ebb80'),
#  'followers': 785,
#  'screen_name': 'sinconedionline',
#  'tweets': 16767}
# {'_id': ObjectId('63e3b54bbeb9905c522ebb8d'),
#  'followers': 78144,
#  'screen_name': 'FelipeTraballi',
#  'tweets': 16692}
# {'_id': ObjectId('63e3b544beb9905c522e9284'),
#  'followers': 2184,
#  'screen_name': 'tatitosi',
#  'tweets': 16671}
# {'_id': ObjectId('63e3b543beb9905c522e8e41'),
#  'followers': 207,
#  'screen_name': 'ruiva_',
#  'tweets': 16665}
# {'_id': ObjectId('63e3b55fbeb9905c522f38bd'),
#  'followers': 1033,
#  'screen_name': 'pollysrocha',
#  'tweets': 16633}
# {'_id': ObjectId('63e3b560beb9905c522f40d2'),
#  'followers': 47,
#  'screen_name': 'CRF_Marcus',
#  'tweets': 16562}
# {'_id': ObjectId('63e3b561beb9905c522f4631'),
#  'followers': 920,
#  'screen_name': 'Dillan_',
#  'tweets': 16550}
# {'_id': ObjectId('63e3b562beb9905c522f508e'),
#  'followers': 234,
#  'screen_name': 'Leandro_SMoura',
#  'tweets': 16513}
# {'_id': ObjectId('63e3b555beb9905c522f003a'),
#  'followers': 244,
#  'screen_name': 'Dgiacometti',
#  'tweets': 16496}
# {'_id': ObjectId('63e3b55cbeb9905c522f2b67'),
#  'followers': 537,
#  'screen_name': 'futebolseriea',
#  'tweets': 16471}
# {'_id': ObjectId('63e3b543beb9905c522e8920'),
#  'followers': 597,
#  'screen_name': 'kassant_',
#  'tweets': 16438}
# {'_id': ObjectId('63e3b557beb9905c522f0c18'),
#  'followers': 479,
#  'screen_name': 'ThaiisMarterer',
#  'tweets': 16349}
# {'_id': ObjectId('63e3b560beb9905c522f3fcd'),
#  'followers': 2501,
#  'screen_name': 'JustinBrazilFC',
#  'tweets': 16233}
# {'_id': ObjectId('63e3b561beb9905c522f4824'),
#  'followers': 3171,
#  'screen_name': 'colmeiablog',
#  'tweets': 16118}
# {'_id': ObjectId('63e3b555beb9905c522efecd'),
#  'followers': 695,
#  'screen_name': 'geekionizado',
#  'tweets': 15908}
# {'_id': ObjectId('63e3b552beb9905c522eeae6'),
#  'followers': 599,
#  'screen_name': 'scilaa',
#  'tweets': 15869}
# {'_id': ObjectId('63e3b554beb9905c522efaa3'),
#  'followers': 689,
#  'screen_name': 'DivinoBlog',
#  'tweets': 15842}
# {'_id': ObjectId('63e3b55dbeb9905c522f2c70'),
#  'followers': 703,
#  'screen_name': 'nandosantos',
#  'tweets': 15837}
# {'_id': ObjectId('63e3b553beb9905c522ef25c'),
#  'followers': 250,
#  'screen_name': 'thaelmpeixoto',
#  'tweets': 15827}
# {'_id': ObjectId('63e3b558beb9905c522f0f42'),
#  'followers': 195,
#  'screen_name': 'biiasc',
#  'tweets': 15812}
# {'_id': ObjectId('63e3b547beb9905c522ea4be'),
#  'followers': 1105,
#  'screen_name': 'Camila_maral',
#  'tweets': 15802}
# {'_id': ObjectId('63e3b55dbeb9905c522f2e4f'),
#  'followers': 649,
#  'screen_name': 'neiducca',
#  'tweets': 15736}
# {'_id': ObjectId('63e3b553beb9905c522ef34f'),
#  'followers': 402,
#  'screen_name': 'thellofilipe',
#  'tweets': 15707}
# {'_id': ObjectId('63e3b562beb9905c522f50ba'),
#  'followers': 6745,
#  'screen_name': 'therabbit',
#  'tweets': 15680}
# {'_id': ObjectId('63e3b551beb9905c522ee51c'),
#  'followers': 1030,
#  'screen_name': 'AnA__Poffo__SC',
#  'tweets': 15671}
# {'_id': ObjectId('63e3b55dbeb9905c522f3008'),
#  'followers': 191,
#  'screen_name': 'karenguassu',
#  'tweets': 15660}
# {'_id': ObjectId('63e3b558beb9905c522f14a7'),
#  'followers': 57,
#  'screen_name': 'walkindisasters',
#  'tweets': 15631}
# {'_id': ObjectId('63e3b55abeb9905c522f1dc3'),
#  'followers': 23643,
#  'screen_name': 'nomll',
#  'tweets': 15631}
# {'_id': ObjectId('63e3b561beb9905c522f45a5'),
#  'followers': 514,
#  'screen_name': 'naaatt_',
#  'tweets': 15624}
# {'_id': ObjectId('63e3b55dbeb9905c522f301f'),
#  'followers': 514,
#  'screen_name': 'naaatt_',
#  'tweets': 15618}
# {'_id': ObjectId('63e3b553beb9905c522ef069'),
#  'followers': 469,
#  'screen_name': 'isadoranassif',
#  'tweets': 15607}
# {'_id': ObjectId('63e3b554beb9905c522efb4c'),
#  'followers': 3428,
#  'screen_name': 'twitcaco',
#  'tweets': 15601}
# {'_id': ObjectId('63e3b561beb9905c522f46df'),
#  'followers': 1348,
#  'screen_name': 'ViniSprada',
#  'tweets': 15585}
# {'_id': ObjectId('63e3b543beb9905c522e8b0c'),
#  'followers': 424,
#  'screen_name': 'Brunocolis',
#  'tweets': 15578}
# {'_id': ObjectId('63e3b54abeb9905c522eb71d'),
#  'followers': 475,
#  'screen_name': 'Neverhurtyou',
#  'tweets': 15536}
# {'_id': ObjectId('63e3b553beb9905c522ef558'),
#  'followers': 383,
#  'screen_name': 'bidanha',
#  'tweets': 15529}
# {'_id': ObjectId('63e3b54ebeb9905c522ed605'),
#  'followers': 384,
#  'screen_name': 'bidanha',
#  'tweets': 15522}
# {'_id': ObjectId('63e3b55abeb9905c522f19b1'),
#  'followers': 130,
#  'screen_name': 'marinarama',
#  'tweets': 15519}
# {'_id': ObjectId('63e3b557beb9905c522f0b8d'),
#  'followers': 354,
#  'screen_name': 'caroltod',
#  'tweets': 15511}
# {'_id': ObjectId('63e3b556beb9905c522f0179'),
#  'followers': 3126,
#  'screen_name': 'lufreitas',
#  'tweets': 15475}
# {'_id': ObjectId('63e3b557beb9905c522f0a50'),
#  'followers': 332,
#  'screen_name': 'alexpolicarpo',
#  'tweets': 15466}
# {'_id': ObjectId('63e3b54cbeb9905c522eca13'),
#  'followers': 461,
#  'screen_name': 'kaduvrp',
#  'tweets': 15458}
# {'_id': ObjectId('63e3b557beb9905c522f09f4'),
#  'followers': 1179,
#  'screen_name': 'Vg_urg',
#  'tweets': 15442}
# {'_id': ObjectId('63e3b54cbeb9905c522ec51a'),
#  'followers': 355,
#  'screen_name': 'magoogf',
#  'tweets': 15424}
# {'_id': ObjectId('63e3b548beb9905c522eacd5'),
#  'followers': 354,
#  'screen_name': 'magoogf',
#  'tweets': 15420}
# {'_id': ObjectId('63e3b55cbeb9905c522f2652'),
#  'followers': 4246,
#  'screen_name': 'jessikadiz',
#  'tweets': 15406}
# {'_id': ObjectId('63e3b55abeb9905c522f1baa'),
#  'followers': 232,
#  'screen_name': 'majups_',
#  'tweets': 15389}
# {'_id': ObjectId('63e3b55fbeb9905c522f37fc'),
#  'followers': 1936,
#  'screen_name': 'crgnobre',
#  'tweets': 15387}
# {'_id': ObjectId('63e3b557beb9905c522f0bfe'),
#  'followers': 232,
#  'screen_name': 'majups_',
#  'tweets': 15384}
# {'_id': ObjectId('63e3b54dbeb9905c522ecd4a'),
#  'followers': 7243,
#  'screen_name': 'Reginaldo_MO',
#  'tweets': 15372}
# {'_id': ObjectId('63e3b54bbeb9905c522ebd87'),
#  'followers': 208,
#  'screen_name': 'JeffCarneiro',
#  'tweets': 15371}
# {'_id': ObjectId('63e3b547beb9905c522e9fdd'),
#  'followers': 583,
#  'screen_name': 'elisa_oi',
#  'tweets': 15365}
# {'_id': ObjectId('63e3b550beb9905c522ede12'),
#  'followers': 7321,
#  'screen_name': 'Potterianos',
#  'tweets': 15347}
# {'_id': ObjectId('63e3b555beb9905c522efd81'),
#  'followers': 790,
#  'screen_name': 'nevershoutshits',
#  'tweets': 15345}
# {'_id': ObjectId('63e3b547beb9905c522ea55b'),
#  'followers': 954,
#  'screen_name': '_karlavieira',
#  'tweets': 15332}
# {'_id': ObjectId('63e3b545beb9905c522e9ae1'),
#  'followers': 954,
#  'screen_name': '_karlavieira',
#  'tweets': 15330}
# {'_id': ObjectId('63e3b54fbeb9905c522ed678'),
#  'followers': 790,
#  'screen_name': 'nevershoutshits',
#  'tweets': 15320}
# {'_id': ObjectId('63e3b54dbeb9905c522ecd46'),
#  'followers': 178,
#  'screen_name': 'decoruiz',
#  'tweets': 15313}
# {'_id': ObjectId('63e3b543beb9905c522e8a48'),
#  'followers': 788,
#  'screen_name': 'nevershoutshits',
#  'tweets': 15312}
# {'_id': ObjectId('63e3b55cbeb9905c522f273c'),
#  'followers': 355,
#  'screen_name': 'gdinamite',
#  'tweets': 15284}
# {'_id': ObjectId('63e3b556beb9905c522f0150'),
#  'followers': 429,
#  'screen_name': 'justcraving',
#  'tweets': 15226}
# {'_id': ObjectId('63e3b562beb9905c522f4dd9'),
#  'followers': 2956,
#  'screen_name': 'uniao_fcLS',
#  'tweets': 15183}
# {'_id': ObjectId('63e3b556beb9905c522f0168'),
#  'followers': 1909,
#  'screen_name': 'ohmybabyjustin',
#  'tweets': 15175}
# {'_id': ObjectId('63e3b550beb9905c522edd88'),
#  'followers': 1900,
#  'screen_name': 'ohmybabyjustin',
#  'tweets': 15145}
# {'_id': ObjectId('63e3b54cbeb9905c522ec812'),
#  'followers': 1898,
#  'screen_name': 'ohmybabyjustin',
#  'tweets': 15131}
# {'_id': ObjectId('63e3b558beb9905c522f14b0'),
#  'followers': 544,
#  'screen_name': 'biaahvanilla',
#  'tweets': 15129}
# {'_id': ObjectId('63e3b545beb9905c522e940a'),
#  'followers': 317,
#  'screen_name': 'OJoaoPinheiro',
#  'tweets': 15114}
# {'_id': ObjectId('63e3b554beb9905c522ef6f3'),
#  'followers': 827,
#  'screen_name': 'thahy',
#  'tweets': 15114}
# {'_id': ObjectId('63e3b545beb9905c522e96fc'),
#  'followers': 471,
#  'screen_name': 'carmomichele',
#  'tweets': 15102}
# {'_id': ObjectId('63e3b55bbeb9905c522f1fd7'),
#  'followers': 1809,
#  'screen_name': 'CallMeChaotic',
#  'tweets': 15097}
# {'_id': ObjectId('63e3b54cbeb9905c522ec5f9'),
#  'followers': 302,
#  'screen_name': 'superqueen',
#  'tweets': 15072}
# {'_id': ObjectId('63e3b552beb9905c522ee9e7'),
#  'followers': 413,
#  'screen_name': 'nath_o',
#  'tweets': 15072}
# {'_id': ObjectId('63e3b55bbeb9905c522f21a5'),
#  'followers': 1326,
#  'screen_name': 'BlogTopSpin',
#  'tweets': 15067}
# {'_id': ObjectId('63e3b55bbeb9905c522f20a4'),
#  'followers': 418,
#  'screen_name': 'kassioz',
#  'tweets': 15025}
# {'_id': ObjectId('63e3b55ebeb9905c522f31de'),
#  'followers': 1665,
#  'screen_name': 'joaojg',
#  'tweets': 14993}
# {'_id': ObjectId('63e3b549beb9905c522eb28b'),
#  'followers': 259,
#  'screen_name': 'racuia',
#  'tweets': 14984}
# {'_id': ObjectId('63e3b54abeb9905c522eb923'),
#  'followers': 1028,
#  'screen_name': 'DuduMorato',
#  'tweets': 14960}
# {'_id': ObjectId('63e3b562beb9905c522f5046'),
#  'followers': 1358,
#  'screen_name': 'pH_livediary',
#  'tweets': 14953}
# {'_id': ObjectId('63e3b55ebeb9905c522f37e4'),
#  'followers': 479,
#  'screen_name': 'Mari_Raupp',
#  'tweets': 14941}
# {'_id': ObjectId('63e3b54fbeb9905c522ed90e'),
#  'followers': 4106,
#  'screen_name': 'Nrmachado',
#  'tweets': 14933}
# {'_id': ObjectId('63e3b548beb9905c522ea986'),
#  'followers': 103,
#  'screen_name': 'feeapple',
#  'tweets': 14896}
# {'_id': ObjectId('63e3b545beb9905c522e9831'),
#  'followers': 103,
#  'screen_name': 'feeapple',
#  'tweets': 14890}
# {'_id': ObjectId('63e3b55bbeb9905c522f23a7'),
#  'followers': 1543,
#  'screen_name': 'elfinha',
#  'tweets': 14785}
# {'_id': ObjectId('63e3b543beb9905c522e8925'),
#  'followers': 215,
#  'screen_name': 'rapha_rge',
#  'tweets': 14734}
# {'_id': ObjectId('63e3b558beb9905c522f13d2'),
#  'followers': 362,
#  'screen_name': 'maricotahh',
#  'tweets': 14723}
# {'_id': ObjectId('63e3b553beb9905c522ef0dd'),
#  'followers': 619,
#  'screen_name': 'naahziiinha',
#  'tweets': 14677}
# {'_id': ObjectId('63e3b561beb9905c522f4a23'),
#  'followers': 1450,
#  'screen_name': 'linhaOfensiva',
#  'tweets': 14654}
# {'_id': ObjectId('63e3b557beb9905c522f0998'),
#  'followers': 2533,
#  'screen_name': 'caio_gattuso',
#  'tweets': 14617}
# {'_id': ObjectId('63e3b54cbeb9905c522ec778'),
#  'followers': 151,
#  'screen_name': 'Deley_BH',
#  'tweets': 14611}
# {'_id': ObjectId('63e3b55bbeb9905c522f2202'),
#  'followers': 288,
#  'screen_name': 'CFeeer',
#  'tweets': 14611}
# {'_id': ObjectId('63e3b557beb9905c522f0a10'),
#  'followers': 162,
#  'screen_name': 'LuizaCapeline',
#  'tweets': 14608}
# {'_id': ObjectId('63e3b553beb9905c522eeefd'),
#  'followers': 2001,
#  'screen_name': 'revistamakingof',
#  'tweets': 14601}
# {'_id': ObjectId('63e3b554beb9905c522efbbd'),
#  'followers': 205,
#  'screen_name': 'Pam_tastica',
#  'tweets': 14601}
# {'_id': ObjectId('63e3b552beb9905c522eebec'),
#  'followers': 192,
#  'screen_name': '_Cacardoso',
#  'tweets': 14594}
# {'_id': ObjectId('63e3b54bbeb9905c522ebe78'),
#  'followers': 2530,
#  'screen_name': 'caio_gattuso',
#  'tweets': 14592}
# {'_id': ObjectId('63e3b54abeb9905c522eb77a'),
#  'followers': 2528,
#  'screen_name': 'caio_gattuso',
#  'tweets': 14587}
# {'_id': ObjectId('63e3b561beb9905c522f4a3c'),
#  'followers': 326,
#  'screen_name': 'eduloureiro',
#  'tweets': 14517}
# {'_id': ObjectId('63e3b551beb9905c522ee794'),
#  'followers': 444,
#  'screen_name': 'margaretss',
#  'tweets': 14511}
# {'_id': ObjectId('63e3b54ebeb9905c522ed42d'),
#  'followers': 444,
#  'screen_name': 'margaretss',
#  'tweets': 14505}
# {'_id': ObjectId('63e3b548beb9905c522ea92c'),
#  'followers': 8760,
#  'screen_name': 'ViFerreyra',
#  'tweets': 14478}
# {'_id': ObjectId('63e3b555beb9905c522f00f0'),
#  'followers': 12145,
#  'screen_name': 'laisricon',
#  'tweets': 14467}
# {'_id': ObjectId('63e3b54dbeb9905c522ecb4a'),
#  'followers': 1151,
#  'screen_name': 'VidaDeCinetico',
#  'tweets': 14457}
# {'_id': ObjectId('63e3b561beb9905c522f4658'),
#  'followers': 5208,
#  'screen_name': 'rodrigoplatao',
#  'tweets': 14443}
# {'_id': ObjectId('63e3b554beb9905c522efd38'),
#  'followers': 994,
#  'screen_name': 'deborajns_',
#  'tweets': 14365}
# {'_id': ObjectId('63e3b54dbeb9905c522ecf43'),
#  'followers': 472,
#  'screen_name': 'souquemsou2',
#  'tweets': 14357}
# {'_id': ObjectId('63e3b553beb9905c522ef285'),
#  'followers': 310,
#  'screen_name': 'gui_potter',
#  'tweets': 14351}
# {'_id': ObjectId('63e3b55fbeb9905c522f3d43'),
#  'followers': 1077,
#  'screen_name': 'br_economico',
#  'tweets': 14315}
# {'_id': ObjectId('63e3b558beb9905c522f0f5d'),
#  'followers': 2343,
#  'screen_name': 'MashQueMash',
#  'tweets': 14292}
# {'_id': ObjectId('63e3b557beb9905c522f093b'),
#  'followers': 2345,
#  'screen_name': 'MashQueMash',
#  'tweets': 14289}
# {'_id': ObjectId('63e3b547beb9905c522ea054'),
#  'followers': 673,
#  'screen_name': 'v_fox',
#  'tweets': 14283}
# {'_id': ObjectId('63e3b543beb9905c522e8840'),
#  'followers': 256,
#  'screen_name': 'RayZiquinatti',
#  'tweets': 14273}
# {'_id': ObjectId('63e3b54ebeb9905c522ed275'),
#  'followers': 163,
#  'screen_name': 'Hericazoo',
#  'tweets': 14273}
# {'_id': ObjectId('63e3b551beb9905c522ee6d0'),
#  'followers': 118,
#  'screen_name': 'leDadalto',
#  'tweets': 14271}
# {'_id': ObjectId('63e3b54fbeb9905c522ed99d'),
#  'followers': 118,
#  'screen_name': 'leDadalto',
#  'tweets': 14266}
# {'_id': ObjectId('63e3b55bbeb9905c522f240b'),
#  'followers': 1957,
#  'screen_name': 'MateusPolli',
#  'tweets': 14253}
# {'_id': ObjectId('63e3b549beb9905c522eb15f'),
#  'followers': 582,
#  'screen_name': 'mandialvarez',
#  'tweets': 14190}
# {'_id': ObjectId('63e3b546beb9905c522e9d4f'),
#  'followers': 326,
#  'screen_name': 'guhs1',
#  'tweets': 14147}
# {'_id': ObjectId('63e3b55ebeb9905c522f35fa'),
#  'followers': 159,
#  'screen_name': 'daariqq',
#  'tweets': 14143}
# {'_id': ObjectId('63e3b558beb9905c522f1379'),
#  'followers': 272,
#  'screen_name': 'matheusbrasil',
#  'tweets': 14082}
# {'_id': ObjectId('63e3b555beb9905c522f0068'),
#  'followers': 153,
#  'screen_name': 'lihbarros',
#  'tweets': 14081}
# {'_id': ObjectId('63e3b561beb9905c522f4761'),
#  'followers': 757,
#  'screen_name': 'bruhgoncalves',
#  'tweets': 14060}
# {'_id': ObjectId('63e3b554beb9905c522efc36'),
#  'followers': 8305,
#  'screen_name': 'luansilvareal',
#  'tweets': 14037}
# {'_id': ObjectId('63e3b54abeb9905c522ebae0'),
#  'followers': 99,
#  'screen_name': 'oldpolaroid',
#  'tweets': 13965}
# {'_id': ObjectId('63e3b555beb9905c522eff8b'),
#  'followers': 821,
#  'screen_name': 'IsaMoraaes',
#  'tweets': 13950}
# {'_id': ObjectId('63e3b55dbeb9905c522f2d88'),
#  'followers': 2073,
#  'screen_name': 'rodriguesluana',
#  'tweets': 13859}
# {'_id': ObjectId('63e3b546beb9905c522e9f7c'),
#  'followers': 881,
#  'screen_name': 'bolsinha',
#  'tweets': 13851}
# {'_id': ObjectId('63e3b558beb9905c522f0d91'),
#  'followers': 776,
#  'screen_name': 'dominique_ts',
#  'tweets': 13844}
# {'_id': ObjectId('63e3b543beb9905c522e8cd8'),
#  'followers': 881,
#  'screen_name': 'bolsinha',
#  'tweets': 13843}
# {'_id': ObjectId('63e3b54abeb9905c522eb9e6'),
#  'followers': 263,
#  'screen_name': 'deboramary',
#  'tweets': 13831}
# {'_id': ObjectId('63e3b54cbeb9905c522ec511'),
#  'followers': 1907,
#  'screen_name': 'KobaMeuMarido',
#  'tweets': 13831}
# {'_id': ObjectId('63e3b548beb9905c522eac57'),
#  'followers': 117,
#  'screen_name': 'Caiortega',
#  'tweets': 13829}
# {'_id': ObjectId('63e3b55ebeb9905c522f33c3'),
#  'followers': 302,
#  'screen_name': 'TakeruIzawa',
#  'tweets': 13797}
# {'_id': ObjectId('63e3b558beb9905c522f0d2b'),
#  'followers': 22344,
#  'screen_name': 'IvanZuchi',
#  'tweets': 13796}
# {'_id': ObjectId('63e3b545beb9905c522e9afd'),
#  'followers': 260,
#  'screen_name': 'Stelaanjo',
#  'tweets': 13737}
# {'_id': ObjectId('63e3b558beb9905c522f11c0'),
#  'followers': 570,
#  'screen_name': 'lailafrazao',
#  'tweets': 13718}
# {'_id': ObjectId('63e3b54abeb9905c522eb7c5'),
#  'followers': 2067,
#  'screen_name': 'himynameisbf',
#  'tweets': 13715}
# {'_id': ObjectId('63e3b55bbeb9905c522f1fb8'),
#  'followers': 890,
#  'screen_name': 'oTiagoCarvalho',
#  'tweets': 13714}
# ...
#  'followers': 15,
#  'screen_name': 'jackeline_rc',
#  'tweets': 161}
# {'_id': ObjectId('63e3b551beb9905c522ee532'),
#  'followers': 38,
#  'screen_name': 'ana_aniinhaaa',
#  'tweets': 160}
# {'_id': ObjectId('63e3b55cbeb9905c522f256a'),
#  'followers': 25,
#  'screen_name': 'FelipeJEC',
#  'tweets': 160}
# {'_id': ObjectId('63e3b55cbeb9905c522f2878'),
#  'followers': 64,
#  'screen_name': 'algumparaiba',
#  'tweets': 160}
# {'_id': ObjectId('63e3b55fbeb9905c522f3d5a'),
#  'followers': 17,
#  'screen_name': 'araujomylena',
#  'tweets': 160}
# {'_id': ObjectId('63e3b561beb9905c522f46e2'),
#  'followers': 17,
#  'screen_name': 'silviaseixas',
#  'tweets': 160}
# {'_id': ObjectId('63e3b54bbeb9905c522ec229'),
#  'followers': 36,
#  'screen_name': 'lucasveneziano',
#  'tweets': 159}
# {'_id': ObjectId('63e3b55bbeb9905c522f228d'),
#  'followers': 32,
#  'screen_name': 'Gomntos',
#  'tweets': 159}
# {'_id': ObjectId('63e3b54fbeb9905c522ed65e'),
#  'followers': 29,
#  'screen_name': 'ApoenaMendonca',
#  'tweets': 158}
# {'_id': ObjectId('63e3b54fbeb9905c522edb8a'),
#  'followers': 28,
#  'screen_name': 'HerikaPabline',
#  'tweets': 158}
# {'_id': ObjectId('63e3b54abeb9905c522eb615'),
#  'followers': 63,
#  'screen_name': 'Ana_Obsession',
#  'tweets': 156}
# {'_id': ObjectId('63e3b54abeb9905c522eb7a3'),
#  'followers': 74,
#  'screen_name': 'gakovalevski',
#  'tweets': 155}
# {'_id': ObjectId('63e3b54cbeb9905c522ec9a8'),
#  'followers': 37,
#  'screen_name': 'ALEXLOPES__',
#  'tweets': 155}
# {'_id': ObjectId('63e3b54ebeb9905c522ed529'),
#  'followers': 21,
#  'screen_name': 'Welly_Soares',
#  'tweets': 155}
# {'_id': ObjectId('63e3b557beb9905c522f0a9f'),
#  'followers': 167,
#  'screen_name': 'anne_shinzato',
#  'tweets': 155}
# {'_id': ObjectId('63e3b545beb9905c522e9529'),
#  'followers': 59,
#  'screen_name': 'camilerorato',
#  'tweets': 154}
# {'_id': ObjectId('63e3b556beb9905c522f02eb'),
#  'followers': 13,
#  'screen_name': 'lipenow',
#  'tweets': 154}
# {'_id': ObjectId('63e3b54abeb9905c522eb548'),
#  'followers': 15,
#  'screen_name': 'telleskaka',
#  'tweets': 153}
# {'_id': ObjectId('63e3b55ebeb9905c522f3358'),
#  'followers': 28,
#  'screen_name': 'leobeernardes',
#  'tweets': 153}
# {'_id': ObjectId('63e3b543beb9905c522e892a'),
#  'followers': 49,
#  'screen_name': 'GuiRussiano',
#  'tweets': 152}
# {'_id': ObjectId('63e3b54abeb9905c522eb846'),
#  'followers': 21,
#  'screen_name': 'Welly_Soares',
#  'tweets': 152}
# {'_id': ObjectId('63e3b558beb9905c522f0e53'),
#  'followers': 13,
#  'screen_name': 'aretz11',
#  'tweets': 152}
# {'_id': ObjectId('63e3b551beb9905c522ee2cc'),
#  'followers': 15,
#  'screen_name': 'bmercia',
#  'tweets': 151}
# {'_id': ObjectId('63e3b545beb9905c522e96da'),
#  'followers': 30,
#  'screen_name': 'omarcolla',
#  'tweets': 150}
# {'_id': ObjectId('63e3b548beb9905c522ead2a'),
#  'followers': 25,
#  'screen_name': 'RogerioeIsadora',
#  'tweets': 150}
# {'_id': ObjectId('63e3b54cbeb9905c522ec34b'),
#  'followers': 12,
#  'screen_name': 'Sandrrinhaa',
#  'tweets': 150}
# {'_id': ObjectId('63e3b550beb9905c522edd9c'),
#  'followers': 42,
#  'screen_name': 'niicky_xD',
#  'tweets': 149}
# {'_id': ObjectId('63e3b551beb9905c522ee4eb'),
#  'followers': 36,
#  'screen_name': 'August_Itapoa',
#  'tweets': 149}
# {'_id': ObjectId('63e3b54fbeb9905c522ed703'),
#  'followers': 21,
#  'screen_name': 'Rawrisis',
#  'tweets': 148}
# {'_id': ObjectId('63e3b55ebeb9905c522f30a9'),
#  'followers': 24,
#  'screen_name': 'Picahxuh',
#  'tweets': 148}
# {'_id': ObjectId('63e3b55abeb9905c522f19ff'),
#  'followers': 13,
#  'screen_name': 'crosstheroom',
#  'tweets': 147}
# {'_id': ObjectId('63e3b549beb9905c522eb10a'),
#  'followers': 251,
#  'screen_name': 'LaCancha',
#  'tweets': 146}
# {'_id': ObjectId('63e3b545beb9905c522e969a'),
#  'followers': 10,
#  'screen_name': 'inditi',
#  'tweets': 145}
# {'_id': ObjectId('63e3b54bbeb9905c522ebecd'),
#  'followers': 25,
#  'screen_name': 'alysonmaltar',
#  'tweets': 145}
# {'_id': ObjectId('63e3b54fbeb9905c522edac8'),
#  'followers': 73,
#  'screen_name': 'TheuBiaggi',
#  'tweets': 145}
# {'_id': ObjectId('63e3b558beb9905c522f1071'),
#  'followers': 13,
#  'screen_name': 'endiecscherer',
#  'tweets': 144}
# {'_id': ObjectId('63e3b55abeb9905c522f1907'),
#  'followers': 24,
#  'screen_name': 'Manuela_Klein',
#  'tweets': 144}
# {'_id': ObjectId('63e3b553beb9905c522ef07d'),
#  'followers': 52,
#  'screen_name': 'Cristiano2v',
#  'tweets': 143}
# {'_id': ObjectId('63e3b55bbeb9905c522f1ee9'),
#  'followers': 8,
#  'screen_name': 'Mauro_curitiba',
#  'tweets': 143}
# {'_id': ObjectId('63e3b551beb9905c522ee84f'),
#  'followers': 197,
#  'screen_name': 'LUZIMPRESSA',
#  'tweets': 142}
# {'_id': ObjectId('63e3b54bbeb9905c522ec01f'),
#  'followers': 70,
#  'screen_name': 'moderniza',
#  'tweets': 141}
# {'_id': ObjectId('63e3b54dbeb9905c522ecf49'),
#  'followers': 24,
#  'screen_name': 'marlowjunior',
#  'tweets': 141}
# {'_id': ObjectId('63e3b543beb9905c522e8dc7'),
#  'followers': 389,
#  'screen_name': 'KebBrasilia',
#  'tweets': 140}
# {'_id': ObjectId('63e3b54fbeb9905c522edb0c'),
#  'followers': 53,
#  'screen_name': 'amadeu',
#  'tweets': 140}
# {'_id': ObjectId('63e3b559beb9905c522f166a'),
#  'followers': 1,
#  'screen_name': 'Kalium32',
#  'tweets': 140}
# {'_id': ObjectId('63e3b55bbeb9905c522f1ff6'),
#  'followers': 34,
#  'screen_name': 'Flavio_Reatto',
#  'tweets': 140}
# {'_id': ObjectId('63e3b546beb9905c522e9cae'),
#  'followers': 51,
#  'screen_name': 'dandip_',
#  'tweets': 139}
# {'_id': ObjectId('63e3b548beb9905c522eaea8'),
#  'followers': 48,
#  'screen_name': 'Bruniinha_Chan',
#  'tweets': 139}
# {'_id': ObjectId('63e3b553beb9905c522ef472'),
#  'followers': 11,
#  'screen_name': 'sbtpaulo',
#  'tweets': 139}
# {'_id': ObjectId('63e3b558beb9905c522f0d05'),
#  'followers': 10,
#  'screen_name': 'OMaltrapa',
#  'tweets': 139}
# {'_id': ObjectId('63e3b55ebeb9905c522f33ac'),
#  'followers': 92,
#  'screen_name': 'nandabender',
#  'tweets': 139}
# {'_id': ObjectId('63e3b561beb9905c522f4624'),
#  'followers': 17,
#  'screen_name': 'silviaseixas',
#  'tweets': 139}
# {'_id': ObjectId('63e3b543beb9905c522e883b'),
#  'followers': 202,
#  'screen_name': 'cleitonk_',
#  'tweets': 138}
# {'_id': ObjectId('63e3b54bbeb9905c522ec293'),
#  'followers': 46,
#  'screen_name': 'sthefaniefava',
#  'tweets': 137}
# {'_id': ObjectId('63e3b54dbeb9905c522ecb37'),
#  'followers': 26,
#  'screen_name': 'Andredesconci',
#  'tweets': 137}
# {'_id': ObjectId('63e3b558beb9905c522f107d'),
#  'followers': 11,
#  'screen_name': 'mariacneves2',
#  'tweets': 137}
# {'_id': ObjectId('63e3b558beb9905c522f112f'),
#  'followers': 30,
#  'screen_name': 'luanaaaoliveira',
#  'tweets': 137}
# {'_id': ObjectId('63e3b543beb9905c522e8b2d'),
#  'followers': 51,
#  'screen_name': 'brevsolucoes',
#  'tweets': 136}
# {'_id': ObjectId('63e3b558beb9905c522f1194'),
#  'followers': 58,
#  'screen_name': 'juliovial',
#  'tweets': 135}
# {'_id': ObjectId('63e3b54bbeb9905c522ebf69'),
#  'followers': 6,
#  'screen_name': 'meriienn',
#  'tweets': 134}
# {'_id': ObjectId('63e3b555beb9905c522efe39'),
#  'followers': 35,
#  'screen_name': 'lurimoraes',
#  'tweets': 134}
# {'_id': ObjectId('63e3b555beb9905c522efe44'),
#  'followers': 16,
#  'screen_name': 'abizarria',
#  'tweets': 134}
# {'_id': ObjectId('63e3b547beb9905c522ea0e9'),
#  'followers': 363,
#  'screen_name': 'felipe_porto',
#  'tweets': 133}
# {'_id': ObjectId('63e3b548beb9905c522eaca1'),
#  'followers': 18,
#  'screen_name': 'caamiilaa__k',
#  'tweets': 133}
# {'_id': ObjectId('63e3b55cbeb9905c522f2754'),
#  'followers': 70,
#  'screen_name': 'fabiana_paes',
#  'tweets': 133}
# {'_id': ObjectId('63e3b557beb9905c522f0959'),
#  'followers': 71,
#  'screen_name': 'bruchayene',
#  'tweets': 132}
# {'_id': ObjectId('63e3b55fbeb9905c522f3b31'),
#  'followers': 20,
#  'screen_name': 'gabrielamolinos',
#  'tweets': 132}
# {'_id': ObjectId('63e3b54cbeb9905c522ec6be'),
#  'followers': 34,
#  'screen_name': 'meucuseucu',
#  'tweets': 131}
# {'_id': ObjectId('63e3b556beb9905c522f01ff'),
#  'followers': 11,
#  'screen_name': 'homocausticus',
#  'tweets': 131}
# {'_id': ObjectId('63e3b547beb9905c522ea260'),
#  'followers': 83,
#  'screen_name': 'raissa_melo',
#  'tweets': 130}
# {'_id': ObjectId('63e3b54cbeb9905c522ec7ff'),
#  'followers': 168,
#  'screen_name': 'johnatas_aloha',
#  'tweets': 130}
# {'_id': ObjectId('63e3b554beb9905c522ef653'),
#  'followers': 11,
#  'screen_name': 'homocausticus',
#  'tweets': 130}
# {'_id': ObjectId('63e3b560beb9905c522f4235'),
#  'followers': 20,
#  'screen_name': 'Jaaassa',
#  'tweets': 130}
# {'_id': ObjectId('63e3b561beb9905c522f486f'),
#  'followers': 42,
#  'screen_name': 'Netofreitasfm',
#  'tweets': 130}
# {'_id': ObjectId('63e3b54ebeb9905c522ed36d'),
#  'followers': 4,
#  'screen_name': '1guibellotti',
#  'tweets': 128}
# {'_id': ObjectId('63e3b549beb9905c522eafa8'),
#  'followers': 46,
#  'screen_name': 'caiobrossi',
#  'tweets': 127}
# {'_id': ObjectId('63e3b54cbeb9905c522ec95e'),
#  'followers': 38,
#  'screen_name': 'jeffersonj',
#  'tweets': 127}
# {'_id': ObjectId('63e3b543beb9905c522e8eaf'),
#  'followers': 29,
#  'screen_name': 'GuiBernardii',
#  'tweets': 126}
# {'_id': ObjectId('63e3b559beb9905c522f16fc'),
#  'followers': 37,
#  'screen_name': 'ellyramona',
#  'tweets': 126}
# {'_id': ObjectId('63e3b560beb9905c522f4238'),
#  'followers': 31,
#  'screen_name': 'Claudiana_clau',
#  'tweets': 124}
# {'_id': ObjectId('63e3b544beb9905c522e9398'),
#  'followers': 23,
#  'screen_name': 'ALINEBORBAK',
#  'tweets': 123}
# {'_id': ObjectId('63e3b55cbeb9905c522f2854'),
#  'followers': 21,
#  'screen_name': 'emivalribeiro',
#  'tweets': 123}
# {'_id': ObjectId('63e3b562beb9905c522f4bd3'),
#  'followers': 204,
#  'screen_name': 'mldlittle',
#  'tweets': 123}
# {'_id': ObjectId('63e3b54abeb9905c522eb685'),
#  'followers': 42,
#  'screen_name': 'julianahatem',
#  'tweets': 122}
# {'_id': ObjectId('63e3b54ebeb9905c522ed3f2'),
#  'followers': 29,
#  'screen_name': 'wiltonraus',
#  'tweets': 122}
# {'_id': ObjectId('63e3b55ebeb9905c522f3263'),
#  'followers': 691,
#  'screen_name': 'Flavia_Cintra_',
#  'tweets': 122}
# {'_id': ObjectId('63e3b561beb9905c522f48f0'),
#  'followers': 99,
#  'screen_name': 'UribeNataly',
#  'tweets': 122}
# {'_id': ObjectId('63e3b556beb9905c522f0889'),
#  'followers': 35,
#  'screen_name': 'thiagocgmattos',
#  'tweets': 121}
# {'_id': ObjectId('63e3b554beb9905c522efaae'),
#  'followers': 111,
#  'screen_name': '_preedo',
#  'tweets': 120}
# {'_id': ObjectId('63e3b55ebeb9905c522f3155'),
#  'followers': 35,
#  'screen_name': 'aloadir',
#  'tweets': 120}
# {'_id': ObjectId('63e3b55ebeb9905c522f32aa'),
#  'followers': 26,
#  'screen_name': 'VanessaPetta',
#  'tweets': 120}
# {'_id': ObjectId('63e3b54cbeb9905c522ec449'),
#  'followers': 12,
#  'screen_name': 'Aninhaenf',
#  'tweets': 119}
# {'_id': ObjectId('63e3b553beb9905c522eee3a'),
#  'followers': 115,
#  'screen_name': 'ocn_neto',
#  'tweets': 119}
# {'_id': ObjectId('63e3b55dbeb9905c522f2d04'),
#  'followers': 40,
#  'screen_name': 'Bebell_Brasil',
#  'tweets': 119}
# {'_id': ObjectId('63e3b560beb9905c522f4087'),
#  'followers': 12,
#  'screen_name': 'Joydinha',
#  'tweets': 117}
# {'_id': ObjectId('63e3b544beb9905c522e92b1'),
#  'followers': 36,
#  'screen_name': 'take_it_poma',
#  'tweets': 116}
# {'_id': ObjectId('63e3b54fbeb9905c522edbe1'),
#  'followers': 6,
#  'screen_name': 'meninassuper',
#  'tweets': 116}
# {'_id': ObjectId('63e3b556beb9905c522f01dd'),
#  'followers': 7,
#  'screen_name': 'mattoslud',
#  'tweets': 116}
# {'_id': ObjectId('63e3b548beb9905c522eaaf7'),
#  'followers': 14,
#  'screen_name': 'let_kolikoviski',
#  'tweets': 115}
# {'_id': ObjectId('63e3b547beb9905c522ea32e'),
#  'followers': 24,
#  'screen_name': 'joanaravaglia',
#  'tweets': 114}
# {'_id': ObjectId('63e3b549beb9905c522eb2c6'),
#  'followers': 63,
#  'screen_name': 'lucasoliveira9',
#  'tweets': 114}
# {'_id': ObjectId('63e3b548beb9905c522eae5a'),
#  'followers': 11,
#  'screen_name': 'Sonson_Mc',
#  'tweets': 113}
# {'_id': ObjectId('63e3b54cbeb9905c522ec5cf'),
#  'followers': 66,
#  'screen_name': 'THAISZAVADZKI',
#  'tweets': 113}
# {'_id': ObjectId('63e3b54dbeb9905c522ecc74'),
#  'followers': 31,
#  'screen_name': 'inacio_moraes',
#  'tweets': 113}
# {'_id': ObjectId('63e3b55bbeb9905c522f2047'),
#  'followers': 15,
#  'screen_name': 'MedvetMedeiros',
#  'tweets': 113}
# {'_id': ObjectId('63e3b55fbeb9905c522f3bb4'),
#  'followers': 68,
#  'screen_name': 'DuMarchissolo',
#  'tweets': 113}
# {'_id': ObjectId('63e3b54abeb9905c522eb52c'),
#  'followers': 32,
#  'screen_name': 'raquepazinatto',
#  'tweets': 112}
# {'_id': ObjectId('63e3b54abeb9905c522eb9f0'),
#  'followers': 13,
#  'screen_name': 'ClaudioLaitano',
#  'tweets': 112}
# {'_id': ObjectId('63e3b54bbeb9905c522ebcb0'),
#  'followers': 2,
#  'screen_name': 'bibiteles_valle',
#  'tweets': 112}
# {'_id': ObjectId('63e3b54ebeb9905c522ed2e3'),
#  'followers': 38,
#  'screen_name': 'rafaturis',
#  'tweets': 112}
# {'_id': ObjectId('63e3b547beb9905c522ea3ad'),
#  'followers': 19,
#  'screen_name': 'lopes096',
#  'tweets': 111}
# {'_id': ObjectId('63e3b549beb9905c522eb16e'),
#  'followers': 36,
#  'screen_name': 'GeorgeTUF',
#  'tweets': 111}
# {'_id': ObjectId('63e3b562beb9905c522f4cd1'),
#  'followers': 19,
#  'screen_name': 'Leticia_Lemos',
#  'tweets': 111}
# {'_id': ObjectId('63e3b545beb9905c522e9884'),
#  'followers': 29,
#  'screen_name': 'yin_akami',
#  'tweets': 109}
# {'_id': ObjectId('63e3b55ebeb9905c522f3677'),
#  'followers': 10,
#  'screen_name': '_AnGeLLuS_',
#  'tweets': 109}
# {'_id': ObjectId('63e3b55fbeb9905c522f3f23'),
#  'followers': 65,
#  'screen_name': 'eduroges',
#  'tweets': 109}
# {'_id': ObjectId('63e3b545beb9905c522e9a29'),
#  'followers': 38,
#  'screen_name': '8Lissa8Larissa8',
#  'tweets': 108}
# {'_id': ObjectId('63e3b547beb9905c522ea346'),
#  'followers': 34,
#  'screen_name': 'Tinajocum',
#  'tweets': 108}
# {'_id': ObjectId('63e3b547beb9905c522ea6fa'),
#  'followers': 17,
#  'screen_name': 'Markus1893',
#  'tweets': 108}
# {'_id': ObjectId('63e3b551beb9905c522ee23a'),
#  'followers': 25,
#  'screen_name': 'VivianeLopesBR',
#  'tweets': 108}
# {'_id': ObjectId('63e3b556beb9905c522f0290'),
#  'followers': 38,
#  'screen_name': 'rodrigo_lon',
#  'tweets': 108}
# {'_id': ObjectId('63e3b562beb9905c522f50d0'),
#  'followers': 868,
#  'screen_name': 'Frases_Gordinho',
#  'tweets': 108}
# {'_id': ObjectId('63e3b556beb9905c522f07a5'),
#  'followers': 41,
#  'screen_name': 'jgsoller',
#  'tweets': 107}
# {'_id': ObjectId('63e3b557beb9905c522f0b66'),
#  'followers': 22,
#  'screen_name': 'NayaraOliiver',
#  'tweets': 107}
# {'_id': ObjectId('63e3b55bbeb9905c522f21c6'),
#  'followers': 20,
#  'screen_name': 'carolinygalvao',
#  'tweets': 107}
# {'_id': ObjectId('63e3b55cbeb9905c522f2ab5'),
#  'followers': 8,
#  'screen_name': 'ricalexamaral',
#  'tweets': 107}
# {'_id': ObjectId('63e3b549beb9905c522eb0f5'),
#  'followers': 125,
#  'screen_name': 'joaquim_eduardo',
#  'tweets': 106}
# {'_id': ObjectId('63e3b55ebeb9905c522f3451'),
#  'followers': 45,
#  'screen_name': 'DaNiScHeFeR',
#  'tweets': 106}
# {'_id': ObjectId('63e3b543beb9905c522e8fd3'),
#  'followers': 19,
#  'screen_name': 'Nikitah_Santos',
#  'tweets': 105}
# {'_id': ObjectId('63e3b549beb9905c522eb1fb'),
#  'followers': 29,
#  'screen_name': 'carorline',
#  'tweets': 105}
# {'_id': ObjectId('63e3b558beb9905c522f1454'),
#  'followers': 47,
#  'screen_name': 'diegodlps',
#  'tweets': 105}
# {'_id': ObjectId('63e3b551beb9905c522ee7c3'),
#  'followers': 379,
#  'screen_name': 'ZoomMotel',
#  'tweets': 104}
# {'_id': ObjectId('63e3b545beb9905c522e97d1'),
#  'followers': 33,
#  'screen_name': 'LeRanalle',
#  'tweets': 103}
# {'_id': ObjectId('63e3b546beb9905c522e9dc2'),
#  'followers': 46,
#  'screen_name': 'goulartjessica',
#  'tweets': 103}
# {'_id': ObjectId('63e3b550beb9905c522ee155'),
#  'followers': 23,
#  'screen_name': 'SpeedSucesso',
#  'tweets': 103}
# {'_id': ObjectId('63e3b552beb9905c522eec33'),
#  'followers': 26,
#  'screen_name': 'caiqueruiz',
#  'tweets': 103}
# {'_id': ObjectId('63e3b548beb9905c522ea94f'),
#  'followers': 178,
#  'screen_name': 'projetoemocoes',
#  'tweets': 102}
# {'_id': ObjectId('63e3b551beb9905c522ee7c4'),
#  'followers': 64,
#  'screen_name': 'Moorangooo',
#  'tweets': 102}
# {'_id': ObjectId('63e3b554beb9905c522efcca'),
#  'followers': 13,
#  'screen_name': 'digomarcal',
#  'tweets': 102}
# {'_id': ObjectId('63e3b55fbeb9905c522f38b7'),
#  'followers': 28,
#  'screen_name': 'bruunakroetz',
#  'tweets': 101}
# {'_id': ObjectId('63e3b544beb9905c522e8ffd'),
#  'followers': 217,
#  'screen_name': 'prabrunamartins',
#  'tweets': 100}
# {'_id': ObjectId('63e3b54fbeb9905c522ed6ea'),
#  'followers': 68,
#  'screen_name': 'Geraldo_h',
#  'tweets': 100}
# {'_id': ObjectId('63e3b54fbeb9905c522ed96c'),
#  'followers': 176,
#  'screen_name': 'srta_aninhaah',
#  'tweets': 100}
# {'_id': ObjectId('63e3b556beb9905c522f02a9'),
#  'followers': 45,
#  'screen_name': 'mixixitorres',
#  'tweets': 100}
